# %% [markdown]
# # **References**
# This tutorial is based on https://github.com/hb20007/hands-on-nltk-tutorial

# %% [markdown]
# # 1.1 **Downloading NLTK Libraries:** *Getting ready to start!*

# %%
# We install and import necessary python libraries

# !pip install nltk TwitterSearch unidecode langdetect langid gensim

import nltk # https://www.nltk.org/install.html
import numpy # https://www.scipy.org/install.html
import matplotlib.pyplot # https://matplotlib.org/downloads.html
import tweepy # https://github.com/tweepy/tweepy
import TwitterSearch # https://github.com/ckoepp/TwitterSearch
import unidecode # https://pypi.python.org/pypi/Unidecode
import langdetect # https://pypi.python.org/pypi/langdetect
import langid # https://github.com/saffsd/langid.py
import gensim # https://radimrehurek.com/gensim/install.html


# Nltk has many extra functionalities that can be downloaded

# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('reuters')
# nltk.download('wordnet')
# nltk.download('words')
# nltk.download('brown')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('tagsets')
# nltk.download('maxent_ne_chunker')
# nltk.download('names')

# !apt-get install unzip
# !unzip /root/nltk_data/corpora/reuters.zip -d /root/nltk_data/corpora
# #!unzip /root/nltk_data/corpora/stopwords.zip -d /root/nltk_data/corpora
# #from nltk.corpus import reuters

# %% [markdown]
# # 3.3 **Creating a POS Tagger:** *Creating a Parts Of Speech tagger*

# %% [markdown]
# We can train a classifier to work out which suffixes are most informative for POS tagging. We can begin by finding out what the most common suffixes are

# %%
from nltk.corpus import brown
from nltk import FreqDist

suffix_fdist = FreqDist()
for word in brown.words():
    word = word.lower()
    suffix_fdist[word[-1:]] += 1
    suffix_fdist[word[-2:]] += 1
    suffix_fdist[word[-3:]] += 1
    
suffix_fdist
# Out:
# FreqDist({'e': 202946, ',': 175002, '.': 152999, 's': 128722, 'd': 105687, 't': 94459, 'he': 92084, 'n': 87889, 'a': 74912, 'of': 72978, ...})

# %%
word = brown.words()[0][-3:]
# print(word)
suffix_fdist
# Out:
# FreqDist({'e': 202946, ',': 175002, '.': 152999, 's': 128722, 'd': 105687, 't': 94459, 'he': 92084, 'n': 87889, 'a': 74912, 'of': 72978, ...})

# %%
suffix_fdist
# Out:
# FreqDist({'e': 202946, ',': 175002, '.': 152999, 's': 128722, 'd': 105687, 't': 94459, 'he': 92084, 'n': 87889, 'a': 74912, 'of': 72978, ...})

# %%
word = brown.words()[0]
word, word[-1:]
# Out:
# ('The', 'e')

# %%
common_suffixes = [suffix for (suffix, count) in suffix_fdist.most_common(100)]
common_suffixes[:10]
# Out:
# ['e', ',', '.', 's', 'd', 't', 'he', 'n', 'a', 'of']

# %% [markdown]
# Next, we'll define a feature extractor function which checks a given word for these suffixes:

# %%
def pos_features(word):
    features = {}
    for suffix in common_suffixes:
        features['endswith({})'.format(suffix)] = word.lower().endswith(suffix)
    return features

for k, v in pos_features('test').items():
    if v == True:
        print(k, v)
# Out:
# endswith(t) True
# endswith(st) True

# %%
for k, v in pos_features('noun').items():
    if v == True:
        print(k, v)
# Out:
# endswith(n) True

# %% [markdown]
# Now that we've defined our feature extractor, we can use it to train a new decision tree classifier:

# %%
brown.tagged_words(categories="news")
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
tagged_words = brown.tagged_words(categories='news')
tagged_words[:10]
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN')]

# %%
tagged_words = brown.tagged_words(categories='news')
featuresets = [(pos_features(n), g) for (n,g) in tagged_words]
featuresets[0]
# Out:
# ({'endswith(e)': True,
#   'endswith(,)': False,
#   'endswith(.)': False,
#   'endswith(s)': False,
#   'endswith(d)': False,
#   'endswith(t)': False,
#   'endswith(he)': True,
#   'endswith(n)': False,
#   'endswith(a)': False,
#   'endswith(of)': False,
#   'endswith(the)': True,
#   'endswith(y)': False,
#   'endswith(r)': False,
#   'endswith(to)': False,
#   'endswith(in)': False,
#   'endswith(f)': False,
#   'endswith(o)': False,
#   'endswith(ed)': False,
#   'endswith(nd)': False,
#   'endswith(is)': False,
#   'endswith(on)': False,
#   'endswith(l)': False,
#   'endswith(g)': False,
#   'endswith(and)': False,
#   'endswith(ng)': False,
#   'endswith(er)': False,
#   'endswith(as)': False,
#   'endswith(ing)': False,
#   'endswith(h)': False,
#   'endswith(at)': False,
#   'endswith(es)': False,
#   'endswith(or)': False,
#   'endswith(re)': False,
#   'endswith(it)': False,
#   'endswith(``)': False,
#   'endswith(an)': False,
#   "endswith('')": False,
#   'endswith(m)': False,
#   'endswith(;)': False,
#   'endswith(i)': False,
#   'endswith(ly)': False,
#   'endswith(ion)': False,
#   'endswith(en)': False,
#   'endswith(al)': False,
#   'endswith(?)': False,
#   'endswith(nt)': False,
#   'endswith(be)': False,
#   'endswith(hat)': False,
#   'endswith(st)': False,
#   'endswith(his)': False,
#   'endswith(th)': False,
#   'endswith(ll)': False,
#   'endswith(le)': False,
#   'endswith(ce)': False,
#   'endswith(by)': False,
#   'endswith(ts)': False,
#   'endswith(me)': False,
#   'endswith(ve)': False,
#   "endswith(')": False,
#   'endswith(se)': False,
#   'endswith(ut)': False,
#   'endswith(was)': False,
#   'endswith(for)': False,
#   'endswith(ent)': False,
#   'endswith(ch)': False,
#   'endswith(k)': False,
#   'endswith(w)': False,
#   'endswith(ld)': False,
#   'endswith(`)': False,
#   'endswith(rs)': False,
#   'endswith(ted)': False,
#   'endswith(ere)': False,
#   'endswith(her)': False,
#   'endswith(ne)': False,
#   'endswith(ns)': False,
#   'endswith(ith)': False,
#   'endswith(ad)': False,
#   'endswith(ry)': False,
#   'endswith())': False,
#   'endswith(()': False,
#   'endswith(te)': False,
#   'endswith(--)': False,
#   'endswith(ay)': False,
#   'endswith(ty)': False,
#   'endswith(ot)': False,
#   'endswith(p)': False,
#   'endswith(nce)': False,
#   "endswith('s)": False,
#   'endswith(ter)': False,
#   'endswith(om)': False,
#   'endswith(ss)': False,
#   'endswith(:)': False,
#   'endswith(we)': False,
#   'endswith(are)': False,
#   'endswith(c)': False,
#   'endswith(ers)': False,
#   'endswith(uld)': False,
#   'endswith(had)': False,
#   'endswith(so)': False,
#   'endswith(ey)': False},
#  'AT')

# %%
from nltk import DecisionTreeClassifier
from nltk.classify import accuracy

cutoff = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[cutoff:], featuresets[:cutoff]

# %%
len(featuresets), cutoff
# Out:
# (100554, 10055)

# %%
#classifier = DecisionTreeClassifier.train(train_set) # NLTK is a teaching toolkit which is not really optimized for speed. Therefore, this may take forever. For speed, use scikit-learn for the classifiers.

from nltk.classify import SklearnClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import BernoulliNB
#bayes_classifier = SklearnClassifier(BernoulliNB(), sparse=False).train(train_set)
#svm_classifier = SklearnClassifier(SVC(), sparse=False).train(train_set)
classifier = SklearnClassifier(DecisionTreeClassifier(), sparse=False).train(train_set)
#print(accuracy(classifier, test_set) , accuracy(bayes_classifier, test_set))
#print(accuracy(classifier, test_set) , accuracy(svm_classifier, test_set), accuracy(bayes_classifier, test_set))

# %%
#classifier = DecisionTreeClassifier.train(train_set) # NLTK is a teaching toolkit which is not really optimized for speed. Therefore, this may take forever. For speed, use scikit-learn for the classifiers.

from nltk.classify import SklearnClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import BernoulliNB

classifier = SklearnClassifier(DecisionTreeClassifier(), sparse=False).train(train_set)

# %%
accuracy(classifier, test_set)
# Out:
# 0.6459472899055196

# %%
classifier.classify(pos_features('cats'))
# Out:
# 'NNS'

# %%
classifier.classify(pos_features('Obama'))
# Out:
# 'AT'

# %%
#classifier.pseudocode(depth=4)

# %% [markdown]
# ## Assembling the classifier & Improving it

# %%
# Let's assemble the parts
from nltk.classify import SklearnClassifier
from sklearn.tree import DecisionTreeClassifier
from nltk.corpus import brown
from nltk import FreqDist
from nltk.classify import accuracy

""" Make the FreqDist """
suffix_fdist = FreqDist()
for word in brown.words():
    word = word.lower()
    suffix_fdist[word[-1:]] += 1
    suffix_fdist[word[-2:]] += 1
    suffix_fdist[word[-3:]] += 1

""" Get the Common Suffixes as a list """
common_suffixes = [suffix for (suffix, count) in suffix_fdist.most_common(200)]

""" Define a pos_features function """

def pos_features(word):
    features = {}
    for suffix in common_suffixes:
        features['endswith({})'.format(suffix)] = word.lower().endswith(suffix)
    return features
    
""" Get tagged_words from Brown corpus and define featuresets """
tagged_words = brown.tagged_words(categories='news')
featuresets = [(pos_features(n), g) for (n,g) in tagged_words]

""" Define a cutoff, and make the train and test sets """
cutoff = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[cutoff:], featuresets[:cutoff]

# This may take a few minutes!
""" Let's use the Decision Tree Classifier to train """
classifier = SklearnClassifier(DecisionTreeClassifier(), sparse=False).train(train_set)

# %%
accuracy(classifier, test_set)
# Out:
# 0.6922923918448534

# %%
featuresets[0]
# Out:
# ({'endswith(e)': True,
#   'endswith(,)': False,
#   'endswith(.)': False,
#   'endswith(s)': False,
#   'endswith(d)': False,
#   'endswith(t)': False,
#   'endswith(he)': True,
#   'endswith(n)': False,
#   'endswith(a)': False,
#   'endswith(of)': False,
#   'endswith(the)': True,
#   'endswith(y)': False,
#   'endswith(r)': False,
#   'endswith(to)': False,
#   'endswith(in)': False,
#   'endswith(f)': False,
#   'endswith(o)': False,
#   'endswith(ed)': False,
#   'endswith(nd)': False,
#   'endswith(is)': False,
#   'endswith(on)': False,
#   'endswith(l)': False,
#   'endswith(g)': False,
#   'endswith(and)': False,
#   'endswith(ng)': False,
#   'endswith(er)': False,
#   'endswith(as)': False,
#   'endswith(ing)': False,
#   'endswith(h)': False,
#   'endswith(at)': False,
#   'endswith(es)': False,
#   'endswith(or)': False,
#   'endswith(re)': False,
#   'endswith(it)': False,
#   'endswith(``)': False,
#   'endswith(an)': False,
#   "endswith('')": False,
#   'endswith(m)': False,
#   'endswith(;)': False,
#   'endswith(i)': False,
#   'endswith(ly)': False,
#   'endswith(ion)': False,
#   'endswith(en)': False,
#   'endswith(al)': False,
#   'endswith(?)': False,
#   'endswith(nt)': False,
#   'endswith(be)': False,
#   'endswith(hat)': False,
#   'endswith(st)': False,
#   'endswith(his)': False,
#   'endswith(th)': False,
#   'endswith(ll)': False,
#   'endswith(le)': False,
#   'endswith(ce)': False,
#   'endswith(by)': False,
#   'endswith(ts)': False,
#   'endswith(me)': False,
#   'endswith(ve)': False,
#   "endswith(')": False,
#   'endswith(se)': False,
#   'endswith(ut)': False,
#   'endswith(was)': False,
#   'endswith(for)': False,
#   'endswith(ent)': False,
#   'endswith(ch)': False,
#   'endswith(k)': False,
#   'endswith(w)': False,
#   'endswith(ld)': False,
#   'endswith(`)': False,
#   'endswith(rs)': False,
#   'endswith(ted)': False,
#   'endswith(ere)': False,
#   'endswith(her)': False,
#   'endswith(ne)': False,
#   'endswith(ns)': False,
#   'endswith(ith)': False,
#   'endswith(ad)': False,
#   'endswith(ry)': False,
#   'endswith())': False,
#   'endswith(()': False,
#   'endswith(te)': False,
#   'endswith(--)': False,
#   'endswith(ay)': False,
#   'endswith(ty)': False,
#   'endswith(ot)': False,
#   'endswith(p)': False,
#   'endswith(nce)': False,
#   "endswith('s)": False,
#   'endswith(ter)': False,
#   'endswith(om)': False,
#   'endswith(ss)': False,
#   'endswith(:)': False,
#   'endswith(we)': False,
#   'endswith(are)': False,
#   'endswith(c)': False,
#   'endswith(ers)': False,
#   'endswith(uld)': False,
#   'endswith(had)': False,
#   'endswith(so)': False,
#   'endswith(ey)': False,
#   'endswith(all)': False,
#   'endswith(one)': False,
#   'endswith(us)': False,
#   'endswith(not)': False,
#   'endswith(ow)': False,
#   'endswith(ons)': False,
#   'endswith(!)': False,
#   'endswith(et)': False,
#   'endswith(out)': False,
#   'endswith(ave)': False,
#   'endswith(ar)': False,
#   'endswith(ge)': False,
#   'endswith(ic)': False,
#   'endswith(de)': False,
#   'endswith(red)': False,
#   'endswith(if)': False,
#   'endswith(ht)': False,
#   'endswith(up)': False,
#   'endswith(no)': False,
#   'endswith(but)': False,
#   'endswith(ght)': False,
#   'endswith(rom)': False,
#   'endswith(id)': False,
#   'endswith(ds)': False,
#   'endswith(ore)': False,
#   'endswith(ate)': False,
#   'endswith(ity)': False,
#   'endswith(een)': False,
#   'endswith(ver)': False,
#   'endswith(hen)': False,
#   'endswith(ke)': False,
#   'endswith(ess)': False,
#   'endswith(ive)': False,
#   'endswith(ble)': False,
#   'endswith(u)': False,
#   'endswith(ich)': False,
#   'endswith(-)': False,
#   'endswith(ies)': False,
#   'endswith(ill)': False,
#   'endswith(hey)': False,
#   'endswith(ned)': False,
#   'endswith(ome)': False,
#   'endswith(ir)': False,
#   'endswith(lly)': False,
#   'endswith(ny)': False,
#   'endswith(rd)': False,
#   'endswith(ck)': False,
#   'endswith(ew)': False,
#   'endswith(ou)': False,
#   'endswith(you)': False,
#   'endswith(rt)': False,
#   'endswith(sed)': False,
#   'endswith(my)': False,
#   'endswith(ur)': False,
#   'endswith(nts)': False,
#   'endswith(ct)': False,
#   'endswith(em)': False,
#   'endswith(im)': False,
#   'endswith(wn)': False,
#   'endswith(ls)': False,
#   'endswith(gh)': False,
#   'endswith(ure)': False,
#   'endswith(our)': False,
#   'endswith(do)': False,
#   'endswith(she)': False,
#   'endswith(own)': False,
#   'endswith(led)': False,
#   'endswith(any)': False,
#   'endswith(eir)': False,
#   'endswith(cal)': False,
#   'endswith(him)': False,
#   'endswith(man)': False,
#   'endswith(est)': False,
#   'endswith(ee)': False,
#   'endswith(od)': False,
#   'endswith(can)': False,
#   'endswith(ded)': False,
#   'endswith(nal)': False,
#   'endswith(use)': False,
#   'endswith(aid)': False,
#   'endswith(has)': False,
#   'endswith(its)': False,
#   'endswith(ms)': False,
#   'endswith(ugh)': False,
#   'endswith(ial)': False,
#   'endswith(ely)': False,
#   'endswith(uch)': False,
#   'endswith(der)': False,
#   'endswith(ard)': False,
#   'endswith(ho)': False,
#   'endswith(ain)': False,
#   'endswith(ous)': False,
#   'endswith(who)': False,
#   'endswith(ant)': False,
#   'endswith(ame)': False,
#   'endswith(nly)': False,
#   'endswith(ost)': False,
#   'endswith(ust)': False,
#   'endswith(ral)': False,
#   'endswith(1)': False},
#  'AT')

# %%
# Let's see the accuracy
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.6922923918448534

# %% [markdown]
# To improve the classifier, we can add contextual features:
#
# Instead of working with tagged words, let's work with tagged sentences:
# ```py
# tagged_sents = brown.tagged_sents(categories='news')
# ```
#
# Now our input looks like:
#
# tagged_sents[0] -> [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'), ... ]
#
# We can then improve this further by adding more features such as `prev-tag` etc.

# %%
""" Let's try incorporating some new features into a classifier
Make sure to use nltk's DecisionTree, so we can visualize the decision tree
"""

# Use the following imports:
from nltk.classify import SklearnClassifier
from sklearn.svm import SVC

def pos_features(sentence, i):
    """ Code here """
    features = {}
    # For each word, let's add four types of features:
    # 1. The last character of the word 
    # 2. The last two characters of the word 
    # 3. The last three characters of the word 
    features = {"suffix(1)":sentence[i][-1:],
    "suffix(2)":sentence[i][-2:],
    "suffix(3)":sentence[i][-3:],
    }
    # 4. The current's word's previous word (in the sentence)
    

    return features

# %%
ex_sent = ['hello', 'my','name']
pos_features(ex_sent,0)
# Out:
# {'suffix(1)': 'o', 'suffix(2)': 'lo', 'suffix(3)': 'llo'}

# %%
def pos_features(sentence, i):
    """ Code here """
    features = {}
    # For each word, let's add four types of features:
    # 1. The last character of the word 
    
    # 2. The last two characters of the word
    
    # 3. The last three characters of the word
    features = {"suffix(1)":sentence[i][-1:],
    "suffix(2)":sentence[i][-2:],
    "suffix(3)":sentence[i][-3:],
    }
    # 4. The current's word's previous word (in the sentence)

    if i == 0:
      features['prev-word'] = '<START>'
    else:
      features['prev-word'] = sentence[i-1]

    if i == len(sentence)-1:
      features["next-word"] = '<END>'
    else:
      features['next-word'] = sentence[i+1]

    if i == 0 or i==1:
      features["prev2-word"] = '<START>'
    else:
      features['prev2-word'] = sentence[i-2]

    return features

print(ex_sent)
print(pos_features(ex_sent, 2))
# Out:
# ['hello', 'my', 'name']
# {'suffix(1)': 'e', 'suffix(2)': 'me', 'suffix(3)': 'ame', 'prev-word': 'my', 'next-word': '<END>', 'prev2-word': 'hello'}

# %%
""" Let's train using the new features  """
from nltk.classify import SklearnClassifier
from sklearn.svm import SVC
#from sklearn.tree import DecisionTreeClassifier

""" This time, we get tagged_sents instead of tagged words """
tagged_sents = brown.tagged_sents(categories='news')

""" Next, make featuresets with our new pos_features function"""
featuresets = []
for tagged_sent in tagged_sents:
  untagged_sent = nltk.tag.untag(tagged_sent)
  for i, (word, tag) in enumerate(tagged_sent):
    featuresets.append((pos_features(untagged_sent,i), tag))

""" Define a cutoff, and make the train and test sets """
cutoff = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[cutoff:], featuresets[:cutoff]


""" First use NLTK so we can see decision tree """
classifier = nltk.DecisionTreeClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.7522625559423173

# %%
classifier.classify(pos_features(['i', 'like', 'cats'], 1))
# Out:
# 'VB'

# %%
classifier.classify(pos_features(['president', 'Obama'], 0))
# Out:
# 'NN'

# %%
featuresets[0]
# Out:
# ({'suffix(1)': 'e',
#   'suffix(2)': 'he',
#   'suffix(3)': 'The',
#   'prev-word': '<START>',
#   'next-word': 'Fulton',
#   'prev2-word': '<START>'},
#  'AT')

# %%
# We can visualize nltk's decision tree!
print(classifier.pseudocode(depth=10))
# Out:
# if suffix(3) == '!':
#   if prev2-word == '$14': return '.-HL'
#   if prev2-word == "''": return '.'
#   if prev2-word == 'about': return '.'
#   if prev2-word == 'blood': return '.'
#   if prev2-word == 'burden': return '.'
#   if prev2-word == 'Damascus': return '.'
#   if prev2-word == 'de': return '.'
#   if prev2-word == 'entertaining': return '.'
#   if prev2-word == 'Fall': return '.'
#   if prev2-word == 'for': return '.-HL'
#   if prev2-word == 'goodness': return '.'
#   if prev2-word == 'had': return '.'
#   if prev2-word == 'it': return '.'
#   if prev2-word == 'Jane': return '.'
#   if prev2-word == 'luck': return '.'
#   if prev2-word == 'of': return '.'
#   if prev2-word == 'parties': return '.'
#   if prev2-word == 'plans': return '.'
#   if prev2-word == 'precedent': return '.'
#   if prev2-word == 'read': return '.'
#   if prev2-word == 'sake': return '.'
#   if prev2-word == 'sang': return '.'
#   if prev2-word == 'Sentry': return '.'
#   if prev2-word == 'started': return '.'
#   if prev2-word == 'Unconscionable': return '.'
#   if prev2-word == "woman's": return '.'
#   if prev2-word == 'yesteryear': return '.'
# if suffix(3) == '$1': return 'NN'
# if suffix(3) == '$10': return 'NNS'
# if suffix(3) == '$14':
#   if next-word == '!': return 'NNS-HL'
#   if next-word == '.': return 'NNS'
# if suffix(3) == '$15': return 'NNS'
# if suffix(3) == '$16': return 'NNS'
# if suffix(3) == '$17': return 'NNS'
# if suffix(3) == '$18': return 'NNS'
# if suffix(3) == '$2': return 'NNS'
# if suffix(3) == '$20': return 'NNS'
# if suffix(3) == '$22': return 'NNS'
# if suffix(3) == '$25': return 'NNS'
# if suffix(3) == '$28': return 'NNS'
# if suffix(3) == '$37': return 'NNS'
# if suffix(3) == '$40': return 'NNS'
# if suffix(3) == '$45': return 'NNS'
# if suffix(3) == '$5': return 'NNS'
# if suffix(3) == '$50': return 'NNS'
# if suffix(3) == '$60': return 'NNS'
# if suffix(3) == '$65': return 'NNS'
# if suffix(3) == '$70': return 'NNS'
# if suffix(3) == '$75': return 'NNS'
# if suffix(3) == '$8': return 'NNS'
# if suffix(3) == '$80': return 'NNS'
# if suffix(3) == '$85': return 'NNS'
# if suffix(3) == '$9': return 'NNS'
# if suffix(3) == '$90': return 'NNS'
# if suffix(3) == '&':
#   if next-word == '8': return 'CC-TL'
#   if next-word == 'A': return 'CC'
#   if next-word == 'Aj': return 'CC'
#   if next-word == 'AM': return 'CC'
#   if next-word == 'Anderson': return 'CC-TL'
#   if next-word == 'Co.': return 'CC-TL'
#   if next-word == 'Company': return 'CC-TL'
#   if next-word == 'Howell': return 'CC-TL'
#   if next-word == 'Indians': return 'CC-HL'
#   if next-word == 'M': return 'CC'
#   if next-word == 'O': return 'CC'
#   if next-word == "O's": return 'CC'
#   if next-word == 'O-B': return 'CC'
#   if next-word == 'O.': return 'CC-TL'
#   if next-word == 'Ohio': return 'CC-TL'
#   if next-word == "Poor's": return 'CC-TL'
#   if next-word == 'Savings': return 'CC-TL'
#   if next-word == 'Son': return 'CC-TL'
#   if next-word == 'Turner': return 'CC-TL'
# if suffix(3) == "'": return "'"
# if suffix(3) == "''": return "''"
# if suffix(3) == "'49": return 'CD'
# if suffix(3) == "'51": return 'CD'
# if suffix(3) == "'52": return 'CD'
# if suffix(3) == "'55": return 'CD'
# if suffix(3) == "'em": return 'PPO'
# if suffix(3) == "'ll":
#   if next-word == 'also': return 'PPSS+MD'
#   if next-word == 'be':
#     if prev2-word == ',': return 'PPSS+MD'
#     if prev2-word == '<START>': return 'PPS+MD'
#     if prev2-word == 'but': return 'PPS+MD'
#     if prev2-word == 'know': return 'PPS+MD'
#     if prev2-word == 'Mets': return 'PPS+MD'
#   if next-word == 'beat': return 'PPSS+MD'
#   if next-word == 'do': return 'PPSS+MD'
#   if next-word == 'even': return 'PPS+MD'
#   if next-word == 'find': return 'PPSS+MD'
#   if next-word == 'get': return 'PPSS+MD'
#   if next-word == 'give': return 'PPSS+MD'
#   if next-word == 'have': return 'PPSS+MD'
#   if next-word == 'let': return 'PPSS+MD'
#   if next-word == 'move':
#     if prev2-word == '<START>': return 'PPS+MD'
#     if prev2-word == 'I': return 'PPSS+MD'
#   if next-word == 'need': return 'PPSS+MD'
#   if next-word == 'never': return 'PPSS+MD'
#   if next-word == 'not': return 'PPSS+MD'
#   if next-word == 'notice': return 'PPSS+MD'
#   if next-word == 'probably': return 'PPSS+MD'
#   if next-word == 'put': return 'PPSS+MD'
#   if next-word == 'start': return 'PPSS+MD'
#   if next-word == 'take': return 'PPSS+MD'
#   if next-word == 'think': return 'PPSS+MD'
#   if next-word == 'wed': return 'PPS+MD'
#   if next-word == 'work': return 'PPSS+MD'
#   if next-word == 'write': return 'PPSS+MD'
# if suffix(3) == "'re": return 'PPSS+BER'
# if suffix(3) == "'ve": return 'PPSS+HV'
# if suffix(3) == '(':
#   if prev-word == '$9': return '('
#   if prev-word == "''": return '('
#   if prev-word == '(': return '('
#   if prev-word == '--': return '('
#   if prev-word == '11': return '(-HL'
#   if prev-word == '149': return '('
#   if prev-word == '17': return '(-HL'
#   if prev-word == '24': return '(-HL'
#   if prev-word == '6-3-3': return '('
#   if prev-word == '7': return '(-HL'
#   if prev-word == '9': return '(-HL'
#   if prev-word == '<START>': return '('
#   if prev-word == '``': return '('
#   if prev-word == 'A.': return '('
#   if prev-word == 'accordion': return '('
#   if prev-word == 'Albany': return '('
#   if prev-word == 'America': return '('
#   if prev-word == 'and': return '('
#   if prev-word == 'Auburn': return '('
#   if prev-word == 'average': return '('
#   if prev-word == 'baseball': return '('
#   if prev-word == 'Bertorelli': return '('
#   if prev-word == 'billion': return '('
#   if prev-word == 'bloc': return '('
#   if prev-word == 'Bob': return '('
#   if prev-word == 'body': return '('
#   if prev-word == 'boy': return '('
#   if prev-word == 'C.': return '('
#   if prev-word == 'California': return '('
#   if prev-word == 'century': return '('
#   if prev-word == 'chemistry': return '('
#   if prev-word == 'Colmer': return '('
#   if prev-word == 'Committee': return '('
#   if prev-word == 'Congolese': return '('
#   if prev-word == 'considered': return '('
#   if prev-word == 'cooking': return '('
#   if prev-word == 'corn': return '('
#   if prev-word == 'Council': return '('
#   if prev-word == 'displays': return '('
#   if prev-word == 'Electra': return '('
#   if prev-word == 'exaggeration': return '('
#   if prev-word == 'Fabian': return '('
#   if prev-word == 'Federation': return '('
#   if prev-word == 'form': return '('
#   if prev-word == 'Foxx': return '('
#   if prev-word == 'Gehrig': return '('
#   if prev-word == 'George': return '('
#   if prev-word == 'Geraghty': return '('
#   if prev-word == 'Greenberg': return '('
#   if prev-word == 'Grove': return '(-HL'
#   if prev-word == 'growth': return '('
#   if prev-word == 'Gus': return '('
#   if prev-word == 'he': return '('
#   if prev-word == 'Herman': return '('
#   if prev-word == 'Hillsboro': return '(-HL'
#   if prev-word == 'House': return '('
#   if prev-word == 'Jimmy': return '('
#   if prev-word == 'Joe': return '('
#   if prev-word == 'Johnson': return '('
#   if prev-word == 'Joseph': return '('
#   if prev-word == 'Laos': return '('
#   if prev-word == 'league': return '('
#   if prev-word == 'legislation': return '('
#   if prev-word == 'maker': return '('
#   if prev-word == 'months': return '('
#   if prev-word == 'Morehouse': return '('
#   if prev-word == 'muscular': return '('
#   if prev-word == 'Musica': return '('
#   if prev-word == 'noticed': return '('
#   if prev-word == 'Ohio': return '(-HL'
#   if prev-word == 'Oil': return '('
#   if prev-word == 'Oklahoma': return '('
#   if prev-word == 'order': return '('
#   if prev-word == 'Palmer': return '('
#   if prev-word == 'passing': return '('
#   if prev-word == 'persons': return '('
#   if prev-word == 'plate': return '('
#   if prev-word == 'pools': return '('
#   if prev-word == 'President': return '('
#   if prev-word == 'priced': return '('
#   if prev-word == 'Professors': return '('
#   if prev-word == 'public': return '('
#   if prev-word == 'record': return '('
#   if prev-word == 'right': return '('
#   if prev-word == 'rooms': return '('
#   if prev-word == 'runs': return '('
#   if prev-word == 'Salem': return '(-HL'
#   if prev-word == 'Schaefer': return '('
#   if prev-word == 'season': return '('
#   if prev-word == 'Senate': return '('
#   if prev-word == 'session': return '('
#   if prev-word == 'sold': return '('
#   if prev-word == 'stations': return '('
#   if prev-word == 'summer': return '('
#   if prev-word == 'tease': return '('
#   if prev-word == "That's": return '('
#   if prev-word == 'the': return '('
#   if prev-word == 'they': return '('
#   if prev-word == 'those': return '('
#   if prev-word == 'three-man': return '('
#   if prev-word == 'tournament': return '('
#   if prev-word == 'transportation': return '('
#   if prev-word == 'USSR': return '('
#   if prev-word == 'volunteers': return '('
#   if prev-word == 'Washington': return '(-HL'
#   if prev-word == 'We': return '('
#   if prev-word == 'Week': return '('
#   if prev-word == 'when': return '('
#   if prev-word == 'White': return '('
#   if prev-word == 'Wilson': return '('
#   if prev-word == 'written': return '('
#   if prev-word == 'yards': return '('
#   if prev-word == 'York': return '(-HL'
# if suffix(3) == ')':
#   if prev-word == "''": return ')'
#   if prev-word == '1': return ')'
#   if prev-word == '10:30': return ')'
#   if prev-word == '126': return ')'
#   if prev-word == '189': return ')'
#   if prev-word == '1910': return ')'
#   if prev-word == '1930': return ')'
#   if prev-word == '1932': return ')'
#   if prev-word == '1938': return ')'
#   if prev-word == '1943': return ')'
#   if prev-word == '1958': return ')'
#   if prev-word == '1960': return ')'
#   if prev-word == '1961': return ')'
#   if prev-word == '2': return ')'
#   if prev-word == '211': return ')'
#   if prev-word == '214': return ')'
#   if prev-word == '215': return ')'
#   if prev-word == '224-170': return ')'
#   if prev-word == '228-229': return ')'
#   if prev-word == '29': return ')'
#   if prev-word == '3': return ')'
#   if prev-word == '4': return ')'
#   if prev-word == '7': return ')'
#   if prev-word == '8:30': return ')'
#   if prev-word == '9:30': return ')'
#   if prev-word == '<START>': return ')'
#   if prev-word == 'ankles': return ')'
#   if prev-word == 'AP': return ')-HL'
#   if prev-word == 'ARF': return ')'
#   if prev-word == 'Arshinkoff': return ')'
#   if prev-word == 'attend': return ')'
#   if prev-word == 'Babe': return ')'
#   if prev-word == 'Baltimore': return ')'
#   if prev-word == 'bedroom': return ')'
#   if prev-word == 'Bevo': return ')'
#   if prev-word == 'Bill': return ')'
#   if prev-word == 'Caesar': return ')'
#   if prev-word == 'Cal.': return ')'
#   if prev-word == 'Calmer': return ')'
#   if prev-word == 'certain': return ')'
#   if prev-word == 'Children': return ')'
#   if prev-word == 'Chronicle': return ')'
#   if prev-word == 'Cincinnati': return ')'
#   if prev-word == 'City': return ')'
#   if prev-word == 'completed': return ')'
#   if prev-word == 'Congo': return ')'
#   if prev-word == 'Congolese': return ')'
#   if prev-word == 'convertible': return ')'
#   if prev-word == 'daily': return ')'
#   if prev-word == 'decision-making': return ')'
#   if prev-word == 'detectives': return ')'
#   if prev-word == 'dividend': return ')'
#   if prev-word == 'employees': return ')'
#   if prev-word == 'Fifth': return ')'
#   if prev-word == 'Forte': return ')'
#   if prev-word == 'Geraghty': return ')'
#   if prev-word == 'goal': return ')'
#   if prev-word == 'Group': return ')'
#   if prev-word == 'had': return ')'
#   if prev-word == 'heather': return ')'
#   if prev-word == 'hemisphere': return ')'
#   if prev-word == 'him': return ')'
#   if prev-word == 'Idaho': return ')'
#   if prev-word == 'Indiana': return ')'
#   if prev-word == 'Industry': return ')'
#   if prev-word == 'Isaacson': return ')'
#   if prev-word == 'Joey': return ')'
#   if prev-word == 'Kasavubu': return ')'
#   if prev-word == 'kicking': return ')'
#   if prev-word == 'Lane': return ')'
#   if prev-word == 'left-handed': return ')'
#   if prev-word == 'Liston': return ')'
#   if prev-word == 'Lumumba': return ')'
#   if prev-word == 'material': return ')'
#   if prev-word == 'Monk': return ')'
#   if prev-word == 'N.D.': return ')'
#   if prev-word == 'N.Y.': return ')'
#   if prev-word == 'neck': return ')'
#   if prev-word == 'Negro': return ')'
#   if prev-word == 'neutral': return ')'
#   if prev-word == 'news': return ')'
#   if prev-word == 'November': return ')'
#   if prev-word == 'One': return ')'
#   if prev-word == 'out': return ')'
#   if prev-word == 'Papa': return ')'
#   if prev-word == 'passing': return ')'
#   if prev-word == 'phrase': return ')'
#   if prev-word == 'plenty': return ')'
#   if prev-word == 'pools': return ')'
#   if prev-word == 'project': return ')'
#   if prev-word == 'Republican': return ')'
#   if prev-word == 'runs': return ')'
#   if prev-word == 'says': return ')'
#   if prev-word == 'school': return ')'
#   if prev-word == 'share': return ')'
#   if prev-word == 'Slim': return ')'
#   if prev-word == 'slip': return ')'
#   if prev-word == 'special': return ')-HL'
#   if prev-word == 'subsidy': return ')'
#   if prev-word == 'teardrop': return ')'
#   if prev-word == 'Thornton': return ')'
#   if prev-word == 'tosses': return ')'
#   if prev-word == 'Tshombe': return ')'
#   if prev-word == 'university': return ')'
#   if prev-word == 'UPI': return ')-HL'
#   if prev-word == 'vote': return ')'
#   if prev-word == 'votes': return ')'
#   if prev-word == 'year': return ')'
#   if prev-word == 'Yogi': return ')'
# if suffix(3) == ',':
#   if next-word == '$1.5': return ','
#   if next-word == '$18.9': return ','
#   if next-word == '$26,000,000': return ','
#   if next-word == '$75': return ','
#   if next-word == "'": return ','
#   if next-word == ',': return ','
#   if next-word == '1': return ','
#   if next-word == '1044': return ','
#   if next-word == '11': return ','
#   if next-word == '1215': return ','
#   if next-word == '13': return ','
#   if next-word == '130': return ','
#   if next-word == '14': return ','
#   if next-word == '1409': return ','
#   if next-word == '145-pound': return ','
#   if next-word == '14th': return ','
#   if next-word == '15': return ','
#   if next-word == '16': return ','
#   if next-word == '1600': return ','
#   if next-word == '16th': return ','
#   if next-word == '17': return ','
#   if next-word == '18': return ','
#   if next-word == '1886': return ','
#   if next-word == '19': return ','
#   if next-word == '1926': return ','
#   if next-word == '1942': return ','
#   if next-word == '1945': return ','
#   if next-word == '1946': return ','
#   if next-word == '195': return ','
#   if next-word == '1951': return ','
#   if next-word == '1957': return ','
#   if next-word == '1958': return ','
#   if next-word == '1959': return ','
#   if next-word == '1960': return ','
#   if next-word == '1960-61': return ','
#   if next-word == '1961': return ','
#   if next-word == '1964': return ','
#   if next-word == '1966': return ','
#   if next-word == '1986': return ','
#   if next-word == '1991': return ','
#   if next-word == '2': return ','
#   if next-word == '20': return ','
#   if next-word == '205-pound': return ','
#   if next-word == '21': return ','
#   if next-word == '22': return ','
#   if next-word == '22-year-old': return ','
#   if next-word == '22111': return ','
#   if next-word == '2269': return ','
#   if next-word == '23': return ','
#   if next-word == '24-inch': return ','
#   if next-word == '25': return ','
#   if next-word == '2544': return ','
#   if next-word == '26': return ','
#   if next-word == '27': return ','
#   if next-word == '2731': return ','
#   if next-word == '2825': return ','
#   if next-word == '29': return ','
#   if next-word == '2d': return ','
#   if next-word == '3': return ','
#   if next-word == '3-0': return ','
#   if next-word == '30th': return ','
#   if next-word == '31': return ','
#   if next-word == '31730': return ','
#   if next-word == '3181': return ','
#   if next-word == '31978': return ','
#   if next-word == '3247': return ','
#   if next-word == '34.7': return ','
#   if next-word == '34220': return ','
#   if next-word == '3505o': return ','
#   if next-word == '355': return ','
#   if next-word == '37': return ','
#   if next-word == '37,000': return ','
#   if next-word == '38': return ','
#   if next-word == '39': return ','
#   if next-word == '4': return ','
#   if next-word == '4-H': return ','
#   if next-word == '41': return ','
#   if next-word == '42': return ','
#   if next-word == '447': return ','
#   if next-word == '45': return ','
#   if next-word == '46': return ','
#   if next-word == '47': return ','
#   if next-word == '5': return ','
#   if next-word == '5-1': return ','
#   if next-word == '5-3': return ','
#   if next-word == '50-year-old': return ','
#   if next-word == '511': return ','
#   if next-word == '5155': return ','
#   if next-word == '52': return ','
#   if next-word == '54': return ','
#   if next-word == '55': return ','
#   if next-word == '57': return ','
#   if next-word == '5835': return ','
#   if next-word == '5847': return ','
#   if next-word == '59': return ','
#   if next-word == '6': return ','
#   if next-word == '6-3': return ','
#   if next-word == '6-foot': return ','
#   if next-word == '60': return ','
#   if next-word == '61': return ','
#   if next-word == '61st': return ','
#   if next-word == '67': return ','
#   if next-word == '67-year-old': return ','
#   if next-word == '676': return ','
#   if next-word == '68': return ','
#   if next-word == '69': return ','
#   if next-word == '695': return ','
#   if next-word == '7034': return ','
#   if next-word == '71': return ','
#   if next-word == '72': return ','
#   if next-word == '76': return ','
#   if next-word == '8': return ','
#   if next-word == '80': return ','
#   if next-word == '9': return ','
#   if next-word == '900,000': return ','
#   if next-word == '9230': return ','
#   if next-word == '9329': return ','
#   if next-word == '<END>': return ','
#   if next-word == '``': return ','
#   if next-word == 'a': return ','
#   if next-word == 'A.': return ','
#   if next-word == 'about': return ','
#   if next-word == 'accompanied': return ','
#   if next-word == 'according': return ','
#   if next-word == 'acquittal': return ','
#   if next-word == 'acrobatic': return ','
#   if next-word == 'activities': return ','
#   if next-word == 'actually': return ','
#   if next-word == 'Adam': return ','
#   if next-word == 'added': return ','
#   if next-word == 'adding': return ','
#   if next-word == 'addresses': return ','
#   if next-word == 'adds': return ','
#   if next-word == 'adequate': return ','
#   if next-word == 'admitted': return ','
#   if next-word == 'advertising-conscious': return ','
#   if next-word == 'AF': return ','
#   if next-word == 'afford': return ','
#   if next-word == 'AFL-CIO': return ','
#   if next-word == 'Africa': return ','
#   if next-word == 'Afro-Cuban': return ','
#   if next-word == 'after': return ','
#   if next-word == 'again': return ','
#   if next-word == 'against': return ','
#   if next-word == 'agriculture': return ','
#   if next-word == 'air': return ','
#   if next-word == 'Aj': return ','
#   if next-word == 'Al': return ','
#   if next-word == 'Ala.':
#     if prev2-word == '<START>': return ',-HL'
#     if prev2-word == 'in': return ','
#     if prev2-word == 'of': return ','
#   if next-word == 'Albany': return ','
#   if next-word == 'Albert': return ','
#   if next-word == 'Alfred': return ','
#   if next-word == 'Alice': return ','
#   if next-word == 'all': return ','
#   if next-word == 'allegedly': return ','
#   if next-word == 'alleging': return ','
#   if next-word == 'Allied': return ','
#   if next-word == "Allison's": return ','
#   if next-word == 'allowed': return ','
#   if next-word == 'allowing': return ','
#   if next-word == 'along': return ','
#   if next-word == 'already': return ','
#   if next-word == 'also': return ','
#   if next-word == 'altho': return ','
#   if next-word == 'although': return ','
#   if next-word == 'American': return ','
#   if next-word == 'among': return ','
#   if next-word == 'amount': return ','
#   if next-word == 'an': return ','
#   if next-word == 'Anaconda': return ','
#   if next-word == 'ancestor': return ','
#   if next-word == 'and': return ','
#   if next-word == 'Angelo': return ','
#   if next-word == 'animals': return ','
#   if next-word == 'Anne': return ','
#   if next-word == 'announce': return ','
#   if next-word == 'announced': return ','
#   if next-word == 'another': return ','
#   if next-word == 'Antone': return ','
#   if next-word == 'any': return ','
#   if next-word == 'anywhere': return ','
#   if next-word == 'Anywhere': return ','
#   if next-word == 'Apartment': return ','
#   if next-word == 'apartments': return ','
#   if next-word == 'apparently': return ','
#   if next-word == 'appealed': return ','
#   if next-word == 'appeared': return ','
#   if next-word == 'approved': return ','
#   if next-word == 'approximately': return ','
#   if next-word == 'April':
#     if prev2-word == ',': return ',-HL'
#     if prev2-word == '<START>': return ',-HL'
#     if prev2-word == 'Library': return ','
#     if prev2-word == 'on': return ','
#   if next-word == 'are': return ','
#   if next-word == 'argued': return ','
#   if next-word == 'Ariz.': return ','
#   if next-word == 'Arkansas': return ','
#   if next-word == "Arkansas'": return ','
#   if next-word == 'Armond': return ','
#   if next-word == 'arms': return ','
#   if next-word == 'Arnold': return ','
#   if next-word == 'Art': return ','
#   if next-word == 'art': return ','
#   if next-word == 'as': return ','
#   if next-word == 'asked': return ','
#   if next-word == 'asking': return ','
#   if next-word == 'assistant': return ','
#   if next-word == 'at': return ','
#   if next-word == 'Atlanta': return ','
#   if next-word == 'attacking': return ','
#   if next-word == 'attactive': return ','
#   if next-word == 'Attilio': return ','
#   if next-word == 'attorney': return ','
#   if next-word == 'Attorney': return ','
#   if next-word == 'Aug.': return ','
#   if next-word == 'author': return ','
#   if next-word == 'authoritative': return ','
#   if next-word == 'available': return ','
#   if next-word == 'awaited': return ','
#   if next-word == 'awarded': return ','
#   if next-word == 'awoke': return ','
#   if next-word == 'Babe': return ','
#   if next-word == 'back': return ','
#   if next-word == 'baggage': return ','
#   if next-word == 'Balkanizing': return ','
#   if next-word == 'bang': return ','
#   if next-word == 'barely': return ','
#   if next-word == 'base-runner': return ','
#   if next-word == 'base-stealing': return ','
#   if next-word == 'baseball': return ','
#   if next-word == 'Baseball': return ','
#   if next-word == 'basic': return ','
#   if next-word == 'basketball': return ','
#   if next-word == 'bass': return ','
#   if next-word == 'batting': return ','
#   if next-word == 'Baylor': return ','
#   if next-word == 'be': return ','
#   if next-word == 'beaming': return ','
#   if next-word == 'bearings': return ','
#   if next-word == 'beating': return ','
#   if next-word == 'beautiful': return ','
#   if next-word == 'became': return ','
#   if next-word == 'because': return ','
#   if next-word == 'become': return ','
#   if next-word == 'becomes': return ','
#   if next-word == 'been': return ','
#   if next-word == 'before': return ','
#   if next-word == 'began': return ','
#   if next-word == 'begins': return ','
#   if next-word == 'being': return ','
#   if next-word == 'Beirut': return ','
#   if next-word == 'Ben': return ','
#   if next-word == 'Beneficiary': return ','
#   if next-word == 'Benington': return ','
#   if next-word == 'Berger': return ','
#   if next-word == 'Bernard': return ','
#   if next-word == 'Berry': return ','
#   if next-word == 'Beryl': return ','
#   if next-word == 'bespectacled': return ','
#   if next-word == 'Beverly': return ','
#   if next-word == 'beyond': return ','
#   if next-word == 'bids': return ','
#   if next-word == 'Bill': return ','
#   if next-word == 'biography': return ','
#   if next-word == 'bipartisan': return ','
#   if next-word == 'Blaine': return ','
#   if next-word == 'Blasingame': return ','
#   if next-word == 'blazing': return ','
#   if next-word == 'Bleckley': return ','
#   if next-word == 'blonde': return ','
#   if next-word == 'blues': return ','
#   if next-word == 'board': return ','
#   if next-word == 'Bob': return ','
#   if next-word == 'booklists': return ','
#   if next-word == 'bookseller': return ','
#   if next-word == 'Border': return ','
#   if next-word == 'born': return ','
#   if next-word == 'both': return ','
#   if next-word == 'bounced': return ','
#   if next-word == 'bows': return ','
#   if next-word == 'Braques': return ','
#   if next-word == 'breaking': return ','
#   if next-word == 'breathes': return ','
#   if next-word == 'bric-a-brac': return ','
#   if next-word == 'brick': return ','
#   if next-word == 'bright': return ','
#   if next-word == 'bringing': return ','
#   if next-word == "Britain's": return ','
#   if next-word == 'brochures': return ','
#   if next-word == 'Brooks': return ','
#   if next-word == "Brooks's": return ','
#   if next-word == 'brought': return ','
#   if next-word == 'Bryan': return ','
#   if next-word == 'Buchheister': return ','
#   if next-word == 'bulletins': return ','
#   if next-word == 'burr': return ','
#   if next-word == 'buses': return ','
#   if next-word == 'business': return ','
#   if next-word == 'but': return ','
#   if next-word == 'buy': return ','
#   if next-word == 'buys': return ','
#   if next-word == 'by': return ','
#   if next-word == 'C.': return ','
#   if next-word == 'cab': return ','
#   if next-word == 'Calif.': return ','
#   if next-word == 'California': return ','
#   if next-word == 'called': return ','
#   if next-word == 'Calude': return ','
#   if next-word == 'came': return ','
#   if next-word == 'can': return ','
#   if next-word == "can't": return ','
#   if next-word == "Canada's": return ','
#   if next-word == 'Cantonese': return ','
#   if next-word == 'Capt.': return ','
#   if next-word == 'cardiac': return ','
#   if next-word == 'Carl': return ','
#   if next-word == 'Carol': return ','
#   if next-word == 'Carolyn': return ','
#   if next-word == 'carpeted': return ','
#   if next-word == 'caused': return ','
#   if next-word == 'center': return ','
#   if next-word == 'ceramic': return ','
#   if next-word == 'chairman': return ','
#   if next-word == 'changed': return ','
#   if next-word == 'charged': return ','
#   if next-word == 'Charles': return ','
#   if next-word == 'Charley': return ','
#   if next-word == 'chemicals': return ','
#   if next-word == 'Chicago': return ','
#   if next-word == 'chicken': return ','
#   if next-word == 'chief': return ','
#   if next-word == 'Chiuchow': return ','
#   if next-word == 'chops': return ','
#   if next-word == 'chose': return ','
#   if next-word == 'Christine': return ','
#   if next-word == 'Chrysler': return ','
#   if next-word == 'churches': return ','
#   if next-word == 'Cinemactor': return ','
#   if next-word == 'City': return ','
#   if next-word == 'civil': return ','
#   if next-word == 'claimed': return ','
#   if next-word == 'Clayton': return ','
#   if next-word == 'cleaners': return ','
#   if next-word == 'Clement': return ','
#   if next-word == 'clerk': return ','
#   if next-word == 'Cleveland': return ','
#   if next-word == 'Cliff': return ','
#   if next-word == 'closed-door': return ','
#   if next-word == 'club': return ','
#   if next-word == 'clustered': return ','
#   if next-word == 'coach': return ','
#   if next-word == 'Coach': return ','
#   if next-word == 'coaches': return ','
#   if next-word == 'COAHR': return ','
#   if next-word == 'cobalt': return ','
#   if next-word == 'Cody': return ','
#   if next-word == 'collapsed': return ','
#   if next-word == 'collected': return ','
#   if next-word == 'College': return ','
#   if next-word == 'Colmer': return ','
#   if next-word == 'color': return ','
#   if next-word == 'Columbus': return ','
#   if next-word == 'combined': return ','
#   if next-word == 'come': return ','
#   if next-word == 'comedy': return ','
#   if next-word == 'commencing': return ','
#   if next-word == 'commented': return ','
#   if next-word == 'commenting': return ','
#   if next-word == 'Communist-led': return ','
#   if next-word == 'compacts': return ','
#   if next-word == 'compared': return ','
#   if next-word == 'competitor': return ','
#   if next-word == 'complained': return ','
#   if next-word == 'complaining': return ','
#   if next-word == 'complete': return ','
#   if next-word == 'completes': return ','
#   if next-word == 'complex': return ','
#   if next-word == 'Composite': return ','
#   if next-word == 'concern': return ','
#   if next-word == 'concluded': return ','
#   if next-word == 'conducted': return ','
#   if next-word == 'conductor': return ','
#   if next-word == 'conference': return ','
#   if next-word == 'confessed': return ','
#   if next-word == 'confided': return ','
#   if next-word == 'Congressional': return ','
#   if next-word == 'Conn.': return ','
#   if next-word == 'Connie': return ','
#   if next-word == 'conservative': return ','
#   if next-word == 'considered': return ','
#   if next-word == 'conspired': return ','
#   if next-word == 'contacted': return ','
#   if next-word == 'containing': return ','
#   if next-word == 'continuance': return ','
#   if next-word == 'continue': return ','
#   if next-word == 'continuing': return ','
#   if next-word == 'contributions': return ','
#   if next-word == 'controlled': return ','
#   if next-word == 'cooperating': return ','
#   if next-word == 'cost': return ','
#   if next-word == 'could': return ','
#   if next-word == 'counsel': return ','
#   if next-word == 'counseled': return ','
#   if next-word == 'Courbet': return ','
#   if next-word == 'Cover': return ','
#   if next-word == 'Cranston': return ','
#   if next-word == 'creation': return ','
#   if next-word == 'creator': return ','
#   if next-word == 'Crosby': return ','
#   if next-word == 'crushing': return ','
#   if next-word == 'cultural': return ','
#   if next-word == 'currently': return ','
#   if next-word == 'cut': return ','
#   if next-word == 'D.': return ','
#   if next-word == 'D.C.': return ','
#   if next-word == 'Damascus': return ','
#   if next-word == 'dance': return ','
#   if next-word == 'daring': return ','
#   if next-word == 'Dark': return ','
#   if next-word == 'date': return ','
#   if next-word == 'dated': return ','
#   if next-word == 'daughter': return ','
#   if next-word == 'Dave': return ','
#   if next-word == 'Davenport': return ','
#   if next-word == 'David': return ','
#   if next-word == 'Davis': return ','
#   if next-word == 'dealers': return ','
#   if next-word == 'debuting': return ','
#   if next-word == 'Dec.': return ','
#   if next-word == 'decided': return ','
#   if next-word == 'declaring': return ','
#   if next-word == 'declined': return ','
#   if next-word == 'deducted': return ','
#   if next-word == 'defending': return ','
#   if next-word == 'defends': return ','
#   if next-word == 'defense': return ','
#   if next-word == 'Defense': return ','
#   if next-word == 'delivered': return ','
#   if next-word == 'Deloris': return ','
#   if next-word == 'demanded': return ','
#   if next-word == 'Democrat': return ','
#   if next-word == 'Democratic': return ','
#   if next-word == 'Democratic-sponsored': return ','
#   if next-word == 'depending': return ','
#   if next-word == 'Deputy': return ','
#   if next-word == 'describing': return ','
#   if next-word == 'designed': return ','
#   if next-word == 'designer': return ','
#   if next-word == 'despite': return ','
#   if next-word == 'Detective': return ','
#   if next-word == 'Dick': return ','
#   if next-word == 'Dicks': return ','
#   if next-word == 'Dictator': return ','
#   if next-word == 'did': return ','
#   if next-word == 'died': return ','
#   if next-word == 'dignity': return ','
#   if next-word == 'dimes': return ','
#   if next-word == 'diminutive': return ','
#   if next-word == 'dining': return ','
#   if next-word == 'diocesan': return ','
#   if next-word == 'diplomats': return ','
#   if next-word == 'director': return ','
#   if next-word == 'disclosed': return ','
#   if next-word == 'disclosures': return ','
#   if next-word == 'disgusted': return ','
#   if next-word == 'dispatching': return ','
#   if next-word == 'display': return ','
#   if next-word == 'District': return ','
#   if next-word == 'disturbance': return ','
#   if next-word == 'Diversified': return ','
#   if next-word == 'divided': return ','
#   if next-word == 'Djakarta': return ','
#   if next-word == 'Dodge': return ','
#   if next-word == 'Dodgers': return ','
#   if next-word == 'dog': return ','
#   if next-word == 'doing': return ','
#   if next-word == 'Dominic': return ','
#   if next-word == 'Don': return ','
#   if next-word == 'Donald': return ','
#   if next-word == 'Donnell': return ','
#   if next-word == 'door-fronted': return ','
#   if next-word == 'Dorenzo': return ','
#   if next-word == 'dormitories': return ','
#   if next-word == 'doubled': return ','
#   if next-word == 'doubly': return ','
#   if next-word == 'down': return ','
#   if next-word == 'downed': return ','
#   if next-word == 'Dr.': return ','
#   if next-word == 'dramatic': return ','
#   if next-word == 'Dreamboat': return ','
#   if next-word == 'dressers': return ','
#   if next-word == 'drew': return ','
#   if next-word == 'driers': return ','
#   if next-word == 'drive': return ','
#   if next-word == 'drives': return ','
#   if next-word == 'driving': return ','
#   if next-word == 'drizzly': return ','
#   if next-word == 'dropped': return ','
#   if next-word == 'drove': return ','
#   if next-word == 'due': return ','
#   if next-word == 'dug': return ','
#   if next-word == 'Duncan': return ','
#   if next-word == 'Dunn': return ','
#   if next-word == 'Dwight': return ','
#   if next-word == 'dynamic': return ','
#   if next-word == 'E.': return ','
#   if next-word == 'e.g.': return ','
#   if next-word == 'E.G.T.': return ','
#   if next-word == 'each': return ','
#   if next-word == 'eager': return ','
#   if next-word == 'earlier': return ','
#   if next-word == 'earned': return ','
#   if next-word == 'earnings': return ','
#   if next-word == 'earns': return ','
#   if next-word == 'eased': return ','
#   if next-word == 'East': return ','
#   if next-word == 'eat': return ','
#   if next-word == 'economic': return ','
#   if next-word == 'economics': return ','
#   if next-word == 'economist': return ','
#   if next-word == 'edging': return ','
#   if next-word == 'education': return ','
#   if next-word == 'effective': return ','
#   if next-word == 'either': return ','
#   if next-word == 'El': return ','
#   if next-word == 'Eldon': return ','
#   if next-word == 'Eleanor': return ','
#   if next-word == 'emasculated': return ','
#   if next-word == 'Emory': return ','
#   if next-word == 'emphasizes': return ','
#   if next-word == 'en': return ','
#   if next-word == 'enabling': return ','
#   if next-word == 'ending': return ','
#   if next-word == 'Eng.': return ','
#   if next-word == 'enlivened': return ','
#   if next-word == 'entered': return ','
#   if next-word == 'enterprises': return ','
#   if next-word == 'enterprisingly': return ','
#   if next-word == 'entertained': return ','
#   if next-word == 'enthralling': return ','
#   if next-word == 'Equator': return ','
#   if next-word == 'erasing': return ','
#   if next-word == 'erected': return ','
#   if next-word == 'erupted': return ','
#   if next-word == 'Ervin': return ','
#   if next-word == 'escaped': return ','
#   if next-word == 'escaping': return ','
#   if next-word == 'especially': return ','
#   if next-word == 'essentially': return ','
#   if next-word == 'et': return ','
#   if next-word == 'etc.': return ','
#   if next-word == 'Evanston': return ','
#   if next-word == 'even': return ','
#   if next-word == 'ever': return ','
#   if next-word == 'every': return ','
#   if next-word == 'Everywhere': return ','
#   if next-word == 'exactly': return ','
#   if next-word == 'except': return ','
#   if next-word == 'exec': return ','
#   if next-word == 'executive': return ','
#   if next-word == 'experienced': return ','
#   if next-word == 'experts': return ','
#   if next-word == 'explained': return ','
#   if next-word == 'explains': return ','
#   if next-word == 'expressing': return ','
#   if next-word == 'extra': return ','
#   if next-word == 'F.': return ','
#   if next-word == 'Fabian': return ','
#   if next-word == 'facilities': return ','
#   if next-word == 'factory': return ','
#   if next-word == 'family': return ','
#   if next-word == 'fanned': return ','
#   if next-word == 'fans': return ','
#   if next-word == 'far': return ','
#   if next-word == 'far-flung': return ','
#   if next-word == 'farm': return ','
#   if next-word == 'farmers': return ','
#   if next-word == "farmers'": return ','
#   if next-word == 'fast': return ','
#   if next-word == 'faster': return ','
#   if next-word == 'FBI': return ','
#   if next-word == 'fearing': return ','
#   if next-word == 'featured': return ','
#   if next-word == 'Feb.': return ',-HL'
#   if next-word == 'federalize': return ','
#   if next-word == 'feeling': return ','
#   if next-word == 'few': return ','
#   if next-word == 'fewer': return ','
#   if next-word == 'Fiedler': return ','
#   if next-word == 'Fifth': return ','
#   if next-word == 'Fil': return ','
#   if next-word == 'filed': return ','
#   if next-word == 'filled': return ','
#   if next-word == 'film': return ','
#   if next-word == 'final': return ','
#   if next-word == 'finished': return ','
#   if next-word == 'finned': return ','
#   if next-word == 'First': return ','
#   if next-word == 'first': return ','
#   if next-word == 'five': return ','
#   if next-word == 'Fla.':
#     if prev2-word == '<START>': return ',-HL'
#     if prev2-word == 'in': return ','
#     if prev2-word == 'Palm': return ','
#     if prev2-word == 'St.': return ',-HL'
#     if prev2-word == 'Vero': return ','
#   if next-word == 'flanked': return ','
#   if next-word == 'flew': return ','
#   if next-word == 'followed': return ','
#   if next-word == 'following': return ','
#   if next-word == 'for': return ','
#   if next-word == 'forced': return ','
#   if next-word == 'Ford': return ','
#   if next-word == 'foreign': return ','
#   if next-word == 'Forest': return ','
#   if next-word == 'forgetting': return ','
#   if next-word == 'former': return ','
#   if next-word == 'formerly': return ','
#   if next-word == 'Fortier': return ','
#   if next-word == 'forward': return ','
#   if next-word == 'found': return ','
#   if next-word == 'founder': return ','
#   if next-word == 'four': return ','
#   if next-word == 'fourth': return ','
#   if next-word == 'Fra': return ','
#   if next-word == 'France': return ','
#   if next-word == "France's": return ','
#   if next-word == 'Francis': return ','
#   if next-word == 'Frank': return ','
#   if next-word == 'Frankie': return ','
#   if next-word == 'Franklin': return ','
#   if next-word == 'frankness': return ','
#   if next-word == 'Frederic': return ','
#   if next-word == 'Frederick': return ','
#   if next-word == 'free': return ','
#   if next-word == 'Freeholder': return ','
#   if next-word == 'French': return ','
#   if next-word == 'fresh': return ','
#   if next-word == 'from': return ','
#   if next-word == 'fuller': return ','
#   if next-word == 'functional': return ','
#   if next-word == 'fund-raising': return ','
#   if next-word == 'Fundamental': return ','
#   if next-word == 'G.': return ','
#   if next-word == 'Ga.': return ','
#   if next-word == 'gained': return ','
#   if next-word == 'Gaither': return ','
#   if next-word == 'gangling': return ','
#   if next-word == 'Gannon': return ','
#   if next-word == 'garden': return ','
#   if next-word == 'Garden': return ','
#   if next-word == 'garrulous': return ','
#   if next-word == 'Gary': return ','
#   if next-word == 'gathering': return ','
#   if next-word == 'gave': return ','
#   if next-word == 'general': return ','
#   if next-word == 'General': return ','
#   if next-word == 'Geneticist': return ','
#   if next-word == 'Genevieve': return ','
#   if next-word == 'genial': return ','
#   if next-word == 'geographically': return ','
#   if next-word == 'George': return ','
#   if next-word == "Georgia's": return ','
#   if next-word == 'Gerald': return ','
#   if next-word == 'German': return ','
#   if next-word == 'Germany': return ','
#   if next-word == 'Giants': return ','
#   if next-word == 'Gino': return ','
#   if next-word == 'giving': return ','
#   if next-word == 'glanced': return ','
#   if next-word == 'Glenda': return ','
#   if next-word == 'Gloriana': return ','
#   if next-word == 'go': return ','
#   if next-word == 'goes': return ','
#   if next-word == 'going': return ','
#   if next-word == 'gold': return ','
#   if next-word == 'golden': return ','
#   if next-word == "golf's": return ','
#   if next-word == 'good': return ','
#   if next-word == 'Goodis': return ','
#   if next-word == 'Gordon': return ','
#   if next-word == 'got': return ','
#   if next-word == 'Grace': return ','
#   if next-word == 'Grant': return ','
#   if next-word == 'grapefruit': return ','
#   if next-word == 'gray-haired': return ','
#   if next-word == 'Great': return ','
#   if next-word == 'Greenville': return ','
#   if next-word == 'Greer': return ','
#   if next-word == 'Gregorio': return ','
#   if next-word == 'Guam': return ','
#   if next-word == 'Guerin': return ','
#   if next-word == 'guests': return ','
#   if next-word == 'guided': return ','
#   if next-word == 'Guinea': return ','
#   if next-word == 'Gus': return ','
#   if next-word == 'Guy': return ','
#   if next-word == 'H.': return ','
#   if next-word == 'ha': return ','
#   if next-word == 'had': return ','
#   if next-word == 'Hamilton': return ','
#   if next-word == 'hand-screened': return ','
#   if next-word == 'hand-woven': return ','
#   if next-word == 'handed': return ','
#   if next-word == 'Hansen': return ','
#   if next-word == "Hansen's": return ','
#   if next-word == 'happy': return ','
#   if next-word == 'hardly': return ','
#   if next-word == 'Hardwicke-Etter': return ','
#   if next-word == 'Harry': return ','
#   if next-word == 'Hartweger': return ','
#   if next-word == 'has': return ','
#   if next-word == "hasn't": return ','
#   if next-word == 'have': return ','
#   if next-word == 'he': return ','
#   if next-word == "he'll": return ','
#   if next-word == 'head': return ','
#   if next-word == 'headed': return ','
#   if next-word == 'headmaster': return ','
#   if next-word == 'headquarters': return ','
#   if next-word == 'heavily': return ','
#   if next-word == 'heavy': return ','
#   if next-word == 'held': return ','
#   if next-word == 'Helen': return ','
#   if next-word == 'Hemphill': return ','
#   if next-word == 'Hemus': return ','
#   if next-word == 'Hengesbach': return ','
#   if next-word == 'Henry': return ','
#   if next-word == 'heptachlor': return ','
#   if next-word == 'her': return ','
#   if next-word == 'Herb': return ','
#   if next-word == 'here': return ','
#   if next-word == 'Heritage': return ','
#   if next-word == 'hero': return ','
#   if next-word == 'high': return ','
#   if next-word == 'high-ceilinged': return ','
#   if next-word == 'hiring': return ','
#   if next-word == 'his': return ','
#   if next-word == 'hit': return ','
#   if next-word == 'hits': return ','
#   if next-word == 'hitting': return ','
#   if next-word == 'Hogan': return ','
#   if next-word == 'holders': return ','
#   if next-word == 'holds': return ','
#   if next-word == 'home-run': return ','
#   if next-word == 'honest': return ','
#   if next-word == 'Hong': return ','
#   if next-word == 'Honolulu': return ',-HL'
#   if next-word == 'hope': return ','
#   if next-word == 'hopes': return ','
#   if next-word == 'hoping': return ','
#   if next-word == 'hospital': return ','
#   if next-word == 'hotdogs': return ','
#   if next-word == 'hotel': return ','
#   if next-word == 'hotels': return ','
#   if next-word == 'hours': return ','
#   if next-word == 'how': return ','
#   if next-word == 'however': return ','
#   if next-word == 'Huff': return ','
#   if next-word == 'Hughes': return ','
#   if next-word == 'hundreds': return ','
#   if next-word == 'hurtling': return ','
#   if next-word == 'I': return ','
#   if next-word == "I'm": return ','
#   if next-word == 'i.e.': return ','
#   if next-word == 'identified': return ','
#   if next-word == 'idle': return ','
#   if next-word == 'if': return ','
#   if next-word == 'Ike': return ','
#   if next-word == 'Ill.':
#     if prev2-word == '<START>': return ',-HL'
#     if prev2-word == 'at': return ','
#     if prev2-word == 'in': return ','
#     if prev2-word == 'of': return ','
#   if next-word == 'immediately': return ','
#   if next-word == 'implicit': return ','
#   if next-word == 'impossible': return ','
#   if next-word == 'in': return ','
#   if next-word == 'Inc.': return ','
#   if next-word == 'include': return ','
#   if next-word == 'including': return ','
#   if next-word == 'incredibly': return ','
#   if next-word == 'India': return ','
#   if next-word == 'individuals': return ','
#   if next-word == 'Indonesia': return ','
#   if next-word == 'inevitably': return ','
#   if next-word == 'infantile': return ','
#   if next-word == 'insists': return ','
#   if next-word == 'instead': return ','
#   if next-word == 'interests': return ','
#   if next-word == 'international': return ','
#   if next-word == 'internationalist': return ','
#   if next-word == 'into': return ','
#   if next-word == 'investment': return ','
#   if next-word == 'investors': return ','
#   if next-word == 'invitations': return ','
#   if next-word == 'invoking': return ','
#   if next-word == 'Iowa': return ','
#   if next-word == 'Iran': return ','
#   if next-word == 'Ireland': return ','
#   if next-word == 'irrespective': return ','
#   if next-word == 'Irwin': return ','
#   if next-word == 'is': return ','
#   if next-word == 'Isaac': return ','
#   if next-word == 'issued': return ','
#   if next-word == 'it': return ','
#   if next-word == "it's": return ','
#   if next-word == 'Italian': return ','
#   if next-word == 'its': return ','
#   if next-word == 'J.': return ','
#   if next-word == 'Jack': return ','
#   if next-word == 'James': return ','
#   if next-word == 'Jan.':
#     if prev2-word == '(': return ','
#     if prev2-word == '<START>': return ',-HL'
#     if prev2-word == 'Saturday': return ','
#   if next-word == 'Jana': return ','
#   if next-word == 'Jane': return ','
#   if next-word == 'Janice': return ','
#   if next-word == 'Jay': return ','
#   if next-word == 'Jefferson': return ','
#   if next-word == 'jewels': return ','
#   if next-word == 'Jim': return ','
#   if next-word == 'Jimmy': return ','
#   if next-word == 'Joan': return ','
#   if next-word == 'Joe': return ','
#   if next-word == 'John': return ','
#   if next-word == 'Johnny': return ','
#   if next-word == 'joined': return ','
#   if next-word == 'Jones': return ','
#   if next-word == 'Jorda': return ','
#   if next-word == 'Joseph': return ','
#   if next-word == 'journalist': return ','
#   if next-word == 'Joyce': return ','
#   if next-word == 'Jr.': return ','
#   if next-word == "Jr.'s": return ','
#   if next-word == 'Judge': return ','
#   if next-word == 'Julian': return ','
#   if next-word == 'July': return ','
#   if next-word == 'June':
#     if prev2-word == '<START>': return ',-HL'
#     if prev2-word == 'members': return ','
#     if prev2-word == 'N.': return ',-HL'
#     if prev2-word == 'opening': return ','
#   if next-word == 'jurist': return ','
#   if next-word == 'just': return ','
#   if next-word == 'Justice': return ','
#   if next-word == 'K.J.P.': return ','
#   if next-word == 'Kans.': return ','
#   if next-word == 'Kansas': return ','
#   if next-word == 'Karen': return ','
#   if next-word == 'Karol': return ','
#   if next-word == 'Kas.': return ','
#   if next-word == 'Kasai': return ','
#   if next-word == 'Katanga': return ','
#   if next-word == 'Kathy': return ','
#   if next-word == 'Kay': return ','
#   if next-word == 'Kentfield': return ','
#   if next-word == 'Kentucky': return ','
#   if next-word == 'kept': return ','
#   if next-word == 'Kern': return ','
#   if next-word == 'keynote': return ','
#   if next-word == 'kicks': return ','
#   if next-word == 'kids': return ','
#   if next-word == 'Kimmell': return ','
#   if next-word == 'Kira': return ','
#   if next-word == 'Kivu': return ','
#   if next-word == 'knows': return ','
#   if next-word == 'Kowalski': return ','
#   if next-word == 'Ky.': return ','
#   if next-word == 'L.': return ','
#   if next-word == 'La.':
#     if prev2-word == 'Baton': return ',-HL'
#     if prev2-word == 'New': return ','
#     if prev2-word == 'of': return ','
#   if next-word == 'Labor': return ','
#   if next-word == 'labor': return ','
#   if next-word == 'lacked': return ','
#   if next-word == 'languages': return ','
#   if next-word == 'Larry': return ','
#   if next-word == 'last': return ','
#   if next-word == 'later': return ','
#   if next-word == 'Latin': return ','
#   if next-word == 'Lawrenceville': return ','
#   if next-word == 'lawyer': return ','
# ...
#   if next-word == "Woman's": return 'NP-TL'
#   if next-word == 'won': return 'NP'
# if suffix(3) == 'xec': return 'NN'
# if suffix(3) == 'xed': return 'VBN'
# if suffix(3) == 'xel':
#   if next-word == ',': return 'NP'
#   if next-word == 'collection': return 'NP'
#   if next-word == 'Hill': return 'NP-TL'
#   if next-word == 'of': return 'NP'
#   if next-word == 'Park': return 'NP-TL'
# if suffix(3) == 'xer': return 'NN'
# if suffix(3) == 'xes': return 'NNS'
# if suffix(3) == 'xon': return 'NP'
# if suffix(3) == 'xth':
#   if prev2-word == ',': return 'OD'
#   if prev2-word == 'dropped': return 'OD'
#   if prev2-word == 'in': return 'OD'
#   if prev2-word == 'is': return 'OD'
#   if prev2-word == 'of': return 'OD'
#   if prev2-word == 'taken': return 'OD-TL'
#   if prev2-word == 'winless': return 'OD'
# if suffix(3) == 'xts': return 'NNS'
# if suffix(3) == "y'd": return 'PPSS+MD'
# if suffix(3) == "y's":
#   if next-word == '$100': return 'NN$'
#   if next-word == '.': return 'NP$'
#   if next-word == '1.58': return 'NR$'
#   if next-word == '2': return 'NR$'
#   if next-word == '2,963': return 'NP$'
#   if next-word == '36th': return 'NN$-TL'
#   if next-word == 'accelerated': return 'NN$-TL'
#   if next-word == 'advertising': return 'NN$'
#   if next-word == 'aid': return 'NP$'
#   if next-word == 'Alliance': return 'NP$'
#   if next-word == 'associate': return 'NN$-TL'
#   if next-word == 'biggest': return 'NP$'
#   if next-word == 'blue-uniformed': return 'NN$-TL'
#   if next-word == 'Board': return 'NN$-TL'
#   if next-word == 'brother-in-law': return 'NP$'
#   if next-word == 'charter': return 'NN$-TL'
#   if next-word == 'chief': return 'NN$'
#   if next-word == 'collective': return 'NN$'
#   if next-word == 'contributions': return 'NN$'
#   if next-word == 'Convair': return 'NP$'
#   if next-word == 'debut': return 'NP$'
#   if next-word == 'degree': return 'NN$'
#   if next-word == 'demand': return 'NR$'
#   if next-word == 'design': return 'NR$'
#   if next-word == 'east': return 'NN$'
#   if next-word == 'eight': return 'NN$'
#   if next-word == 'farm': return 'NN$'
#   if next-word == 'faults': return 'NN$'
#   if next-word == 'Fine': return 'NP$'
#   if next-word == 'first': return 'NP$'
#   if next-word == 'fourth': return 'NR$'
#   if next-word == 'future':
#     if prev2-word == '<START>': return 'NN$-HL'
#     if prev2-word == 'of': return 'NN$'
#   if next-word == 'game': return 'NR$'
#   if next-word == 'globe-girdling': return 'NP$'
#   if next-word == 'Golden': return 'NN$'
#   if next-word == 'handsome': return 'NR$'
#   if next-word == 'head': return 'NP$'
#   if next-word == 'Inauguration': return 'NP$'
#   if next-word == 'invitation': return 'NP$'
#   if next-word == 'letters': return 'NR$'
#   if next-word == 'loss': return 'NN$'
#   if next-word == 'losses': return 'NR$'
#   if next-word == 'master': return 'NN$-TL'
#   if next-word == 'mentioned': return 'PN+HVZ'
#   if next-word == 'military': return 'NN$-TL'
#   if next-word == 'most': return 'NN$'
#   if next-word == 'Nautilus': return 'NN$'
#   if next-word == 'need': return 'NR$'
#   if next-word == 'New': return 'NR$'
#   if next-word == 'nominee': return 'NN$-TL'
#   if next-word == 'olive-green': return 'NP$'
#   if next-word == 'open': return 'NR$'
#   if next-word == 'opener': return 'NR$'
#   if next-word == 'own': return 'NP$'
#   if next-word == 'pension': return 'NN$'
#   if next-word == 'performance': return 'NR$'
#   if next-word == 'Polaris': return 'NN$-TL'
#   if next-word == 'population': return 'NN$'
#   if next-word == 'problems': return 'NP$'
#   if next-word == 'requests': return 'NP$'
#   if next-word == 'return': return 'NP$'
#   if next-word == 'rotunda': return 'NN$-TL'
#   if next-word == 'schedule': return 'NN$'
#   if next-word == 'schools': return 'NN$'
#   if next-word == 'secrets': return 'NN$'
#   if next-word == 'services': return 'NN$'
#   if next-word == 'sessions': return 'NR$'
#   if next-word == 'snow': return 'NN$'
#   if next-word == 'Social':
#     if prev2-word == 'that': return 'NP$'
#     if prev2-word == 'the': return 'NN$-TL'
#   if next-word == 'special': return 'NR$'
#   if next-word == 'St.': return 'NP$'
#   if next-word == 'still-building': return 'NN$'
#   if next-word == 'successful': return 'NR$'
#   if next-word == 'trend': return 'NR$'
#   if next-word == 'unexpected': return 'NP$'
#   if next-word == 'victory': return 'NR$'
#   if next-word == 'weekly': return 'NR$'
# if suffix(3) == 'Y.':
#   if next-word == ',': return 'NP-HL'
#   if next-word == '.': return 'NP'
#   if next-word == 'C.': return 'NP'
# if suffix(3) == 'yal':
#   if next-word == 'army': return 'JJ'
#   if next-word == 'family': return 'JJ'
#   if next-word == 'Government': return 'JJ'
#   if next-word == 'Laotian': return 'JJ'
#   if next-word == 'Motel': return 'JJ-TL'
#   if next-word == 'of': return 'NN'
#   if next-word == 'to': return 'JJ'
#   if next-word == 'told': return 'JJ-TL'
#   if next-word == 'was': return 'JJ-TL'
#   if next-word == 'what': return 'NP'
# if suffix(3) == 'yan': return 'NP'
# if suffix(3) == 'ybe': return 'RB'
# if suffix(3) == 'yce': return 'NP'
# if suffix(3) == 'yde': return 'NP'
# if suffix(3) == 'ye': return 'PPSS'
# if suffix(3) == 'yed':
#   if prev-word == ',': return 'VBD'
#   if prev-word == '<START>': return 'VBN'
#   if prev-word == 'a': return 'JJ'
#   if prev-word == 'also': return 'VBD'
#   if prev-word == 'been': return 'VBN'
#   if prev-word == 'Coach': return 'VBD-HL'
#   if prev-word == 'concert': return 'VBN'
#   if prev-word == 'deliberately': return 'VBD'
#   if prev-word == 'green': return 'VBD'
#   if prev-word == 'had': return 'VBN'
#   if prev-word == 'has': return 'VBN'
#   if prev-word == 'have': return 'VBN'
#   if prev-word == 'He': return 'VBD'
#   if prev-word == 'he': return 'VBD'
#   if prev-word == 'institutions': return 'VBN'
#   if prev-word == 'is': return 'VBN'
#   if prev-word == 'Jones': return 'VBD'
#   if prev-word == 'linebackers': return 'VBD'
#   if prev-word == 'loosely': return 'VBN'
#   if prev-word == 'market': return 'VBN'
#   if prev-word == 'Nelson': return 'VBD'
#   if prev-word == 'not': return 'VBN'
#   if prev-word == 'organization': return 'VBD'
#   if prev-word == 'prices': return 'VBD'
#   if prev-word == 'purposely': return 'VBD'
#   if prev-word == 'simply': return 'VBD'
#   if prev-word == 'since': return 'VBN'
#   if prev-word == 'spouse': return 'VBN'
#   if prev-word == 'that': return 'VBD'
#   if prev-word == 'then': return 'VBD'
#   if prev-word == 'they': return 'VBD'
#   if prev-word == 'They': return 'VBD'
#   if prev-word == 'was': return 'VBN'
#   if prev-word == 'week': return 'VBD'
#   if prev-word == 'who': return 'VBD'
# if suffix(3) == 'yee':
#   if prev2-word == ',': return 'NP'
#   if prev2-word == '``': return 'NN'
#   if prev2-word == 'term': return 'NN'
# if suffix(3) == 'yen': return 'NN'
# if suffix(3) == 'yer':
#   if prev-word == '(': return 'NP'
#   if prev-word == ',':
#     if prev2-word == "''": return 'NP'
#     if prev2-word == 'ago': return 'NP'
#     if prev2-word == 'course': return 'NP'
#     if prev2-word == 'journalist': return 'NN'
#     if prev2-word == 'Masters': return 'NP'
#     if prev2-word == 'round': return 'NP'
#   if prev-word == '<START>': return 'NP'
#   if prev-word == 'a': return 'NN'
#   if prev-word == 'American': return 'NN'
#   if prev-word == 'and': return 'NP'
#   if prev-word == 'As': return 'NP'
#   if prev-word == 'B.': return 'NP'
#   if prev-word == 'ball': return 'NN'
#   if prev-word == 'behind': return 'NP'
#   if prev-word == 'both': return 'NP'
#   if prev-word == 'British': return 'NN'
#   if prev-word == 'But': return 'NP'
#   if prev-word == "chapter's": return 'NN'
#   if prev-word == 'complete': return 'NN'
#   if prev-word == 'corporation': return 'NN'
#   if prev-word == 'Dutch': return 'NP'
#   if prev-word == 'Eddie': return 'NP'
#   if prev-word == 'Gary': return 'NP'
#   if prev-word == 'good': return 'NN'
#   if prev-word == 'Kenny': return 'NP'
#   if prev-word == "League's": return 'NN'
#   if prev-word == 'Mrs.': return 'NP'
#   if prev-word == 'Newport-based': return 'NN'
#   if prev-word == 'nor': return 'NP'
#   if prev-word == 'outstanding': return 'NN'
#   if prev-word == 'that': return 'NP'
#   if prev-word == 'The': return 'NN'
#   if prev-word == 'the': return 'NN'
#   if prev-word == 'thin': return 'NN'
#   if prev-word == 'valuable': return 'NN'
#   if prev-word == 'Valuable': return 'NN-TL'
# if suffix(3) == 'yes':
#   if next-word == ',': return 'NP'
#   if next-word == '.': return 'NNS'
#   if next-word == ';':
#     if prev2-word == 'including': return 'NP-TL'
#     if prev2-word == 'their': return 'NNS'
#   if next-word == 'and': return 'NNS'
#   if next-word == 'at': return 'NNS'
#   if next-word == 'could': return 'NNS'
#   if next-word == 'focused': return 'NNS'
#   if next-word == 'for': return 'NNS'
#   if next-word == 'of': return 'NNS'
#   if next-word == 'on': return 'NNS'
#   if next-word == 'said': return 'NP'
#   if next-word == 'that': return 'NNS'
#   if next-word == 'with': return 'NNS'
# if suffix(3) == 'Yes': return 'RB'
# if suffix(3) == 'yet':
#   if prev2-word == '--': return 'RB'
#   if prev2-word == 'allotment': return 'RB'
#   if prev2-word == 'been': return 'RB'
#   if prev2-word == 'is': return 'RB'
#   if prev2-word == 'talking': return 'RB'
#   if prev2-word == 'that': return 'RB'
#   if prev2-word == 'Very': return 'CC'
# if suffix(3) == 'Yet': return 'RB'
# if suffix(3) == 'yfe': return 'NP'
# if suffix(3) == 'yle':
#   if prev2-word == ',': return 'NN'
#   if prev2-word == '<START>': return 'NP'
#   if prev2-word == 'a': return 'JJ-TL'
#   if prev2-word == 'after': return 'NN'
#   if prev2-word == 'at': return 'NP-TL'
#   if prev2-word == 'delicate': return 'NN'
#   if prev2-word == 'in': return 'NN'
#   if prev2-word == 'William': return 'NP'
# if suffix(3) == 'yly': return 'RB'
# if suffix(3) == 'yne':
#   if prev2-word == ',': return 'NP'
#   if prev2-word == '<START>': return 'NP'
#   if prev2-word == 'and': return 'NP'
#   if prev2-word == 'are': return 'NP'
#   if prev2-word == 'at': return 'NP-TL'
#   if prev2-word == 'class': return 'NP'
#   if prev2-word == 'home': return 'NP'
#   if prev2-word == 'honoring': return 'NP'
#   if prev2-word == 'place': return 'NP'
#   if prev2-word == 'room': return 'NP'
#   if prev2-word == 'roommate': return 'NP-TL'
# if suffix(3) == 'ynn': return 'NP'
# if suffix(3) == 'yon': return 'NP'
# if suffix(3) == 'yor':
#   if next-word == '.': return 'NN-TL'
#   if next-word == 'apparently': return 'NN-TL'
#   if next-word == 'declined': return 'NN-TL'
#   if next-word == 'Grady': return 'NN-TL'
#   if next-word == 'is': return 'NN-TL'
#   if next-word == 'James': return 'NN-TL'
#   if next-word == 'Richardson': return 'NN-TL'
#   if next-word == 'said': return 'NN-TL'
#   if next-word == 'spoke': return 'NN-TL'
#   if next-word == 'Terry': return 'NN-TL'
#   if next-word == 'visited': return 'NN-TL'
#   if next-word == 'visits': return 'NN-TL-HL'
#   if next-word == 'Wagner': return 'NN-TL'
#   if next-word == "Wagner's": return 'NN-TL'
# if suffix(3) == 'you':
#   if prev2-word == ',':
#     if next-word == "can't": return 'PPSS'
#     if next-word == 'learn': return 'PPSS'
#     if next-word == 'seek': return 'PPO'
#     if next-word == 'speaking': return 'PPSS'
#   if prev2-word == '--': return 'PPSS'
#   if prev2-word == '<START>': return 'PPSS'
#   if prev2-word == '``': return 'PPSS'
#   if prev2-word == 'a': return 'PPSS'
#   if prev2-word == 'all': return 'PPO'
#   if prev2-word == 'and': return 'PPO'
#   if prev2-word == 'beautiful': return 'PPSS'
#   if prev2-word == 'do': return 'PPSS'
#   if prev2-word == "don't": return 'PPSS'
#   if prev2-word == 'faith': return 'PPSS'
#   if prev2-word == 'foreign': return 'PPSS'
#   if prev2-word == 'generously': return 'PPSS'
#   if prev2-word == 'ham': return 'PPSS'
#   if prev2-word == 'How': return 'PPSS'
#   if prev2-word == 'I': return 'PPO'
#   if prev2-word == "I'll": return 'PPO'
#   if prev2-word == 'Just': return 'PPSS'
#   if prev2-word == 'make': return 'PPSS'
#   if prev2-word == 'passes': return 'PPO'
#   if prev2-word == 'play': return 'PPO'
#   if prev2-word == 'Practice': return 'PPO'
#   if prev2-word == 'size': return 'PPSS'
#   if prev2-word == 'somebody': return 'PPO'
#   if prev2-word == 'talk': return 'PPO'
#   if prev2-word == 'to': return 'PPO'
#   if prev2-word == 'To': return 'PPO'
#   if prev2-word == 'tremendous': return 'PPSS'
#   if prev2-word == 'war': return 'PPSS'
#   if prev2-word == 'way': return 'PPSS'
#   if prev2-word == "we'll": return 'PPO'
#   if prev2-word == 'What': return 'PPSS'
#   if prev2-word == 'Where': return 'PPSS'
#   if prev2-word == 'Why': return 'PPSS'
#   if prev2-word == 'women': return 'PPSS'
#   if prev2-word == 'write': return 'PPSS'
#   if prev2-word == 'you': return 'PPSS'
# if suffix(3) == 'You': return 'PPSS'
# if suffix(3) == 'ype':
#   if prev2-word == 'already': return 'NN'
#   if prev2-word == 'connected': return 'NN'
#   if prev2-word == 'of': return 'NN'
#   if prev2-word == 'spread': return 'JJ'
#   if prev2-word == 'tax': return 'JJ'
#   if prev2-word == 'the': return 'NN'
#   if prev2-word == 'Thousands': return 'JJ'
#   if prev2-word == 'welfare': return 'NN'
# if suffix(3) == 'ypt':
#   if prev2-word == 'at': return 'NN'
#   if prev2-word == 'separated': return 'NP'
# if suffix(3) == 'yre': return 'NP'
# if suffix(3) == "ys'":
#   if next-word == 'day': return 'NP$'
#   if next-word == 'four': return 'NP$'
#   if next-word == 'youngest': return 'NPS$'
# if suffix(3) == 'yte': return 'NP-TL'
# if suffix(3) == 'yth':
#   if prev2-word == 'survey': return 'NP-TL'
#   if prev2-word == 'W.': return 'NP'
# if suffix(3) == 'zan': return 'NP'
# if suffix(3) == 'zed':
#   if prev2-word == ',':
#     if next-word == 'Bernard': return 'VBD'
#     if next-word == 'British': return 'VBN'
#     if next-word == 'March': return 'VBN'
#     if next-word == 'the': return 'VBN'
#   if prev2-word == '<START>':
#     if next-word == '<END>': return 'VBN-HL'
#     if next-word == 'into': return 'VBN'
#   if prev2-word == 'a': return 'VBN'
#   if prev2-word == 'among': return 'VBN'
#   if prev2-word == 'be': return 'VBN'
#   if prev2-word == 'bordering': return 'VBD'
#   if prev2-word == 'boys': return 'VBN'
#   if prev2-word == 'But': return 'VBD'
#   if prev2-word == 'by': return 'VBN'
#   if prev2-word == 'establishing': return 'VBN'
#   if prev2-word == 'expanded': return 'VBD'
#   if prev2-word == 'have': return 'VBN'
#   if prev2-word == 'heels': return 'VBN'
#   if prev2-word == 'in': return 'VBN'
#   if prev2-word == 'is': return 'VBN'
#   if prev2-word == 'last': return 'VBD'
#   if prev2-word == 'late': return 'VBN'
#   if prev2-word == 'merely': return 'VBN'
#   if prev2-word == 'neutralists': return 'VBN'
#   if prev2-word == 'of': return 'VBN'
#   if prev2-word == 'on': return 'VBN'
#   if prev2-word == 'prepared': return 'VBN'
#   if prev2-word == 'qualifications': return 'VBN'
#   if prev2-word == 'sales': return 'VBN'
#   if prev2-word == 'should': return 'VBN'
#   if prev2-word == 'sponsored': return 'VBN'
#   if prev2-word == 'system': return 'VBN'
#   if prev2-word == 'that': return 'VBD'
#   if prev2-word == 'the': return 'VBD'
#   if prev2-word == 'to': return 'VBN'
#   if prev2-word == 'town': return 'VBN'
#   if prev2-word == 'troops': return 'VBD'
#   if prev2-word == 'type': return 'VBN'
#   if prev2-word == 'unions': return 'VBD'
#   if prev2-word == 'was': return 'VBN'
#   if prev2-word == 'which': return 'VBN'
#   if prev2-word == 'will': return 'VBN'
# if suffix(3) == 'zen': return 'NN'
# if suffix(3) == 'zer':
#   if prev2-word == ',': return 'NP'
#   if prev2-word == '<START>': return 'NP'
#   if prev2-word == 'Dr.': return 'NP'
#   if prev2-word == 'of': return 'NN'
# if suffix(3) == 'zes':
#   if prev2-word == '<START>': return 'VBZ'
#   if prev2-word == 'Nassau': return 'VBZ'
#   if prev2-word == 'points': return 'VBZ'
#   if prev2-word == 'the': return 'NNS'
#   if prev2-word == 'which': return 'VBZ'
# if suffix(3) == 'zie':
#   if prev2-word == '3247': return 'NP-TL'
#   if prev2-word == 'Adventures': return 'NP'
# if suffix(3) == 'zio': return 'NP'
# if suffix(3) == 'zle':
#   if prev2-word == 'more': return 'VB'
#   if prev2-word == 'stuck': return 'NN'
# if suffix(3) == 'zly': return 'JJ'
# if suffix(3) == 'Zoe': return 'NP'
# if suffix(3) == 'zog': return 'NP'
# if suffix(3) == 'zon': return 'NN'
# if suffix(3) == 'zza':
#   if prev2-word == ',': return 'NN'
#   if prev2-word == '<START>': return 'NP'
#   if prev2-word == 'by': return 'NP'

# %%
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.7522625559423173

# %%
""" Try Sklearn's decision tree classifier - Does it perform better? """
sklearn_classifier = SklearnClassifier(DecisionTreeClassifier(), sparse=True).train(train_set)
nltk.classify.accuracy(sklearn_classifier, test_set)
# Out:
# 0.8194927896568871

# %%
# Does it correctly tag "cat" now?
print(classifier.classify(pos_features(['there', 'was', 'a','cat'], 3)))
print(sklearn_classifier.classify(pos_features(['there', 'was', 'a','cat'], 3)))
# Out:
# .
# JJ

# %%
print(classifier.classify(pos_features(['there', 'are', 'many','cats'], 3)))
print(sklearn_classifier.classify(pos_features(['there', 'are', 'many','cats'], 3)))
# Out:
# NNS
# NNS-HL

# %%
print(classifier.classify(pos_features(['cat'], 0)))
print(sklearn_classifier.classify(pos_features(['cat'], 0)))
# Out:
# .
# NP-HL

# %%
# Bonus example: Can you Incorporate the tag of the previous word as a feature too?
# Extra example: Incorporate history for sequential tagging

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB

# Can you fill the following function?
def pos_features(sentence, i, history):
    #history=[feature1, featreu2, ...]
     # Reuse the features we used before
     features = features = {"suffix(1)":sentence[i][-1:],
    "suffix(2)":sentence[i][-2:],
    "suffix(3)":sentence[i][-3:],
    }


     # Here, we add additional features
     if i == 0: # This is the start of history
         features["prev-word"] = "<START>"
         features["prev-tag"] = "<START>"
     else: # What should go here?
         features["prev-word"] = sentence[i-1]
         features["prev-tag"] = history[i-1]

     return features

class ConsecutivePosTagger(nltk.TaggerI):

    def __init__(self, train_sents):
        train_set = []
        for tagged_sent in train_sents:
            untagged_sent = nltk.tag.untag(tagged_sent)

            # We now keep track of a history
            history = []
            for i, (word, tag) in enumerate(tagged_sent):
                featureset = pos_features(untagged_sent, i, history)
                train_set.append( (featureset, tag) )
                history.append(tag)
        self.classifier = SklearnClassifier(DecisionTreeClassifier(), sparse=True).train(train_set)

    def tag(self, sentence):
        history = []
        for i, word in enumerate(sentence):
            featureset = pos_features(sentence, i, history)
            tag = self.classifier.classify(featureset)
            history.append(tag)
        return zip(sentence, history)


""" Define a cutoff, and make the train and test sets """
cutoff = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[cutoff:], featuresets[:cutoff]


""" Train & eval """
tagger = ConsecutivePosTagger(train_set)
print(tagger.evaluate(test_set))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/kky8822/2022_AI_expert/0628/practice/Samsung_[Student]_NLTK_Part_1_b.ipynb Cell 47' in <cell line: 54>()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000042vscode-remote?line=49'>50</a> train_set, test_set = featuresets[cutoff:], featuresets[:cutoff]
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000042vscode-remote?line=52'>53</a> """ Train & eval """
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000042vscode-remote?line=53'>54</a> tagger = ConsecutivePosTagger(train_set)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000042vscode-remote?line=54'>55</a> print(tagger.evaluate(test_set))
#
# /home/kky8822/2022_AI_expert/0628/practice/Samsung_[Student]_NLTK_Part_1_b.ipynb Cell 47' in ConsecutivePosTagger.__init__(self, train_sents)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000042vscode-remote?line=26'>27</a> train_set = []
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000042vscode-remote?line=27'>28</a> for tagged_sent in train_sents:
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000042vscode-remote?line=28'>29</a>     untagged_sent = nltk.tag.untag(tagged_sent)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000042vscode-remote?line=30'>31</a>     # We now keep track of a history
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000042vscode-remote?line=31'>32</a>     history = []
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/nltk/tag/util.py:72, in untag(tagged_sentence)
#      61 def untag(tagged_sentence):
#      62     """
#      63     Given a tagged sentence, return an untagged version of that
#      64     sentence.  I.e., return a list containing the first element
#    (...)
#      70
#      71     """
# ---> 72     return [w for (w, t) in tagged_sentence]
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/nltk/tag/util.py:72, in <listcomp>(.0)
#      61 def untag(tagged_sentence):
#      62     """
#      63     Given a tagged sentence, return an untagged version of that
#      64     sentence.  I.e., return a list containing the first element
#    (...)
#      70
#      71     """
# ---> 72     return [w for (w, t) in tagged_sentence]
#
# ValueError: too many values to unpack (expected 2)

# %%
# Let's test it
list(tagger.tag('there was a cat'.split(' ')))

# %% [markdown]
# # 3.4 **Parts of Speech and Meaning (English Only):** *Exploring awesome features offered by WordNet*

# %%
t = "Cyprus, officially the Republic of Cyprus, is an island country in the Eastern Mediterranean and the third largest and third most populous island in the Mediterranean. Cyprus is located south of Turkey, west of Syria and Lebanon, northwest of Israel, north of Egypt, and southeast of Greece. Cyprus is a major tourist destination in the Mediterranean. With an advanced, high-income economy and a very high Human Development Index, the Republic of Cyprus has been a member of the Commonwealth since 1961 and was a founding member of the Non-Aligned Movement until it joined the European Union on 1 May 2004. On 1 January 2008, the Republic of Cyprus joined the eurozone."

# %% [markdown]
# ## 1. Tokenization

# %%
from nltk import sent_tokenize, word_tokenize
sentences = sent_tokenize(t.lower())
sentences
# Out:
# ['cyprus, officially the republic of cyprus, is an island country in the eastern mediterranean and the third largest and third most populous island in the mediterranean.',
#  'cyprus is located south of turkey, west of syria and lebanon, northwest of israel, north of egypt, and southeast of greece.',
#  'cyprus is a major tourist destination in the mediterranean.',
#  'with an advanced, high-income economy and a very high human development index, the republic of cyprus has been a member of the commonwealth since 1961 and was a founding member of the non-aligned movement until it joined the european union on 1 may 2004. on 1 january 2008, the republic of cyprus joined the eurozone.']

# %%
tokens = word_tokenize(sentences[2])
type(tokens)
# Out:
# list

# %% [markdown]
# ## 2. POS Tagging

# %%
from nltk import pos_tag
tags = pos_tag(tokens)
tags
# Out:
# [('cyprus', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('major', 'JJ'),
#  ('tourist', 'NN'),
#  ('destination', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('mediterranean', 'NN'),
#  ('.', '.')]

# %% [markdown]
# To access documentation for tags, for example for `NN`:

# %%
import nltk.help
nltk.help.upenn_tagset('NN')
nltk.help.upenn_tagset('JJ')
nltk.help.upenn_tagset()
# Out:
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %% [markdown]
# ## What is WordNet?
#
# **WordNet** is the lexical database i.e. dictionary for the English language, specifically designed for natural language processing.
#
# **Synset** is a special kind of a simple interface that is present in NLTK to look up words in WordNet. Synset instances are the groupings of synonymous words that express the same concept. Some of the words have only one Synset and some have several.

# %%
# nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /home/kky8822/nltk_data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/kky8822/2022_AI_expert/0628/practice/Samsung_[Student]_NLTK_Part_1_b.ipynb Cell 59' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000138vscode-remote?line=0'>1</a> nltk.download('omw-1.4')
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/nltk/downloader.py:777, in Downloader.download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     768 def show(s, prefix2=""):
#     769     print_to(
#     770         textwrap.fill(
#     771             s,
#    (...)
#     774         )
#     775     )
# --> 777 for msg in self.incr_download(info_or_id, download_dir, force):
#     778     # Error messages
#     779     if isinstance(msg, ErrorMessage):
#     780         show(msg.message)
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/nltk/downloader.py:642, in Downloader.incr_download(self, info_or_id, download_dir, force)
#     638     yield FinishCollectionMessage(info)
#     640 # Handle Packages (delegate to a helper function).
#     641 else:
# --> 642     yield from self._download_package(info, download_dir, force)
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/nltk/downloader.py:708, in Downloader._download_package(self, info, download_dir, force)
#     706 yield ProgressMessage(5)
#     707 try:
# --> 708     infile = urlopen(info.url)
#     709     with open(filepath, "wb") as outfile:
#     710         num_blocks = max(1, info.size / (1024 * 16))
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346 try:
#    1347     try:
# -> 1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1279 def request(self, method, url, body=None, headers={}, *,
#    1280             encode_chunked=False):
#    1281     """Send a complete request to the server."""
# -> 1282     self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/http/client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1324 if isinstance(body, str):
#    1325     # RFC 2616 Section 3.7.1 says that text default has a
#    1326     # default charset of iso-8859-1.
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/http/client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1275 else:
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/http/client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1035 msg = b"\r\n".join(self._buffer)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#    1042     if hasattr(message_body, 'read'):
#    1043         # Let file-like take precedence over byte-like.  This
#    1044         # is needed to allow the current position of mmap'ed
#    1045         # files to be taken into account.
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/http/client.py:975, in HTTPConnection.send(self, data)
#     973 if self.sock is None:
#     974     if self.auto_open:
# --> 975         self.connect()
#     976     else:
#     977         raise NotConnected()
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/http/client.py:1447, in HTTPSConnection.connect(self)
#    1444 def connect(self):
#    1445     "Connect to a host on a given (SSL) port."
# -> 1447     super().connect()
#    1449     if self._tunnel_host:
#    1450         server_hostname = self._tunnel_host
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/http/client.py:941, in HTTPConnection.connect(self)
#     939 """Connect to the host and port specified in __init__."""
#     940 sys.audit("http.client.connect", self, self.host, self.port)
# --> 941 self.sock = self._create_connection(
#     942     (self.host,self.port), self.timeout, self.source_address)
#     943 # Might fail in OSs that don't implement TCP_NODELAY
#     944 try:
#
# File ~/utils/Python/Python-3.10.4/lib/python3.10/socket.py:833, in create_connection(address, timeout, source_address)
#     831 if source_address:
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#     835 err = None
#
# KeyboardInterrupt:

# %%
from nltk.corpus import wordnet

# Understanding Synset
syn = wordnet.synsets('hello')[0]
  
print ("Synset name :  ", syn.name())
  
# Defining the word
print ("\nSynset meaning : ", syn.definition())
  
# list of phrases that use the word in context
print ("\nSynset example : ", syn.examples())
# Out:
# Synset name :   hello.n.01
#
# Synset meaning :  an expression of greeting
#
# Synset example :  ['every morning they exchanged polite hellos']

# %%
wordnet.synsets('water')
# Out:
# [Synset('water.n.01'),
#  Synset('body_of_water.n.01'),
#  Synset('water.n.03'),
#  Synset('water_system.n.02'),
#  Synset('urine.n.01'),
#  Synset('water.n.06'),
#  Synset('water.v.01'),
#  Synset('water.v.02'),
#  Synset('water.v.03'),
#  Synset('water.v.04')]

# %% [markdown]
# ### Hypernyms and Hyponyms –
#
# **Hypernyms**: More abstract terms
#
# **Hyponyms**: More specific terms.
#
# Both come to picture as Synsets are organized in a structure similar to that of an inheritance tree. This tree can be traced all the way up to a root hypernym. Hypernyms provide a way to categorize and group words based on their similarity to each other.

# %%
from nltk.corpus import wordnet

# Understanding Hypernyms and Hyponyms
syn = wordnet.synsets('hello')[0]
  
print ("Synset name :  ", syn.name())
  
print ("\nHYPER abstract term :  ", syn.hypernyms())
  
print ("\nHYPO specific term :  ", 
       syn.hypernyms()[0].hyponyms())
  
syn.root_hypernyms()
  
print ("\nSynset root hypernerm :  ", syn.root_hypernyms())
# Out:
# Synset name :   hello.n.01
#
# HYPER abstract term :   [Synset('greeting.n.01')]
#
# HYPO specific term :   [Synset('calling_card.n.02'), Synset('good_afternoon.n.01'), Synset('good_morning.n.01'), Synset('hail.n.03'), Synset('hello.n.01'), Synset('pax.n.01'), Synset('reception.n.01'), Synset('regard.n.03'), Synset('salute.n.02'), Synset('salute.n.03'), Synset('welcome.n.02'), Synset('well-wishing.n.01')]
#
# Synset root hypernerm :   [Synset('entity.n.01')]

# %%
wordnet.synsets('happy')[0].root_hypernyms()
# Out:
# [Synset('happy.a.01')]

# %%
# POS in Synset
syn = wordnet.synsets('hello')[0]
print ("Syn tag : ", syn.pos())
  
syn = wordnet.synsets('doing')[0]
print ("Syn tag : ", syn.pos())
  
syn = wordnet.synsets('beautiful')[0]
print ("Syn tag : ", syn.pos())
  
syn = wordnet.synsets('quickly')[0]
print ("Syn tag : ", syn.pos())
# Out:
# Syn tag :  n
# Syn tag :  v
# Syn tag :  a
# Syn tag :  r

# %% [markdown]
# ## 3. Word senses (for homonyms)

# %% [markdown]
# WordNet is a lexical database for the English language in the form of a semantic graph.
#
# WordNet groups English words into sets of synonyms called synsets, provides short definitions and usage examples, and records a number of relations among these synonym sets or their members.
#
# NLTK provides an interface to the WordNet API.

# %%
from nltk.corpus import wordnet as wn
wn.synsets('human')
# Out:
# [Synset('homo.n.02'),
#  Synset('human.a.01'),
#  Synset('human.a.02'),
#  Synset('human.a.03')]

# %%
wn.synsets('human')[0].definition()
# Out:
# 'any living or extinct member of the family Hominidae characterized by superior intelligence, articulate speech, and erect carriage'

# %%
wn.synsets('human')[1].definition()
# Out:
# 'characteristic of humanity'

# %%
human = wn.synsets('Human', pos=wn.NOUN)[0]
human
# Out:
# Synset('homo.n.02')

# %%
human.hypernyms() # A hypernym is a word with a broad meaning constituting a category into which words with more specific meanings fall; a superordinate. For example, colour is a hypernym of red.
# Out:
# [Synset('hominid.n.01')]

# %%
human.hyponyms()
# Out:
# [Synset('homo_erectus.n.01'),
#  Synset('homo_habilis.n.01'),
#  Synset('homo_sapiens.n.01'),
#  Synset('homo_soloensis.n.01'),
#  Synset('neandertal_man.n.01'),
#  Synset('rhodesian_man.n.01'),
#  Synset('world.n.08')]

# %%
bike = wn.synsets('bicycle')[0]
bike
# Out:
# Synset('bicycle.n.01')

# %%
girl = wn.synsets('girl')[1]
girl
# Out:
# Synset('female_child.n.01')

# %%
bike.wup_similarity(human) # The Wu-Palmer metric (WUP) is a measure of similarity based on distance in the graph. There are many other metrics too.
# Out:
# 0.34782608695652173

# %%
girl.wup_similarity(human)
# Out:
# 0.5217391304347826

# %%
synonyms = []
for syn in wn.synsets('water'):
    for lemma in syn.lemmas(): #  A lemma is basically the dictionary form or base form of a word, as opposed to the various inflected forms of a word. 
        synonyms.append(lemma.name())
synonyms
# Out:
# ['water',
#  'H2O',
#  'body_of_water',
#  'water',
#  'water',
#  'water_system',
#  'water_supply',
#  'water',
#  'urine',
#  'piss',
#  'pee',
#  'piddle',
#  'weewee',
#  'water',
#  'water',
#  'water',
#  'irrigate',
#  'water',
#  'water',
#  'water']

# %%
antonyms = []
for syn in wn.synsets("girl"):
    for l in syn.lemmas():
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())
antonyms

# %% [markdown]
# ## 4. Chunking and Entity Recognition

# %% [markdown]
# The goal of chunking is to divide a sentence into chunks. Usually each chunk contains a **head** and optionally additionally words and modifiers. Examples of chunks include noun groups and verb groups.

# %% [markdown]
# ### 4.1. Chunking

# %%
from nltk.chunk import RegexpParser

# %% [markdown]
# In order to create a chunker, we need to first define a **chunk grammar**, consisting of rules that indicate how sentences should be chunked.
#
# We can define a simple grammar for a noun phrase (NP) chunker with a single regular-expression rule. This rule says that an NP chunk should be formed whenever the chunker finds an optional determiner (`DT`) followed by any number of adjectives (`JJ`) and then a noun (`NN`).
#
# Note how grammatical structures which are not noun phrases are not chunked, which is totally fine:

# %%
grammar = "NP: {<DT>?<JJ>*<NN>}"

# %%
chunker = RegexpParser(grammar)
result = chunker.parse(tags)
pprint.pprint(result)

# %% [markdown]
# ### 4.2. Entity Recognition

# %% [markdown]
# The goal of entity recogintion is to detect entities such as Person, Location, Time, etc.

# %%
from nltk.chunk import ne_chunk # ne = named entity
pprint.pprint(ne_chunk(tags))

# %% [markdown]
# Note `ne_chunk` was unable to detect any entities in our sentence. That is because it is quite limited, being able to recognize only the following entities:
# > FACILITY, GPE (Geo-Political Entity), GSP (Geo-Socio-Political group), LOCATION, ORGANIZATION, PERSON

# %% [markdown]
# # 3.5 **Trying out Spacy**

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
# Out:
# /home/kky8822/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/spacy/util.py:845: UserWarning: [W094] Model 'en_core_web_sm' (2.2.0) specifies an under-constrained spaCy version requirement: >=2.2.0. This can lead to compatibility problems with older versions, or as new spaCy versions are released, because the model may say it's compatible when it's not. Consider changing the "spacy_version" in your meta.json to a version range, with a lower and upper pin. For example: >=3.3.1,<3.4.0
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /home/kky8822/2022_AI_expert/0628/practice/Samsung_[Student]_NLTK_Part_1_b.ipynb Cell 92' in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000086vscode-remote?line=0'>1</a> import spacy
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/kky8822/2022_AI_expert/0628/practice/Samsung_%5BStudent%5D_NLTK_Part_1_b.ipynb#ch0000086vscode-remote?line=1'>2</a> nlp = spacy.load('en_core_web_sm')
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/spacy/__init__.py:51, in load(name, vocab, disable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      36     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      37 ) -> Language:
#      38     """Load a spaCy model from an installed package or a local path.
#      39
#      40     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/spacy/util.py:420, in load_model(name, vocab, disable, exclude, config)
#     418     return get_lang_class(name.replace("blank:", ""))()
#     419 if is_package(name):  # installed as package
# --> 420     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     421 if Path(name).exists():  # path to model data directory
#     422     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/spacy/util.py:453, in load_model_from_package(name, vocab, disable, exclude, config)
#     438 """Load a model from an installed package.
#     439
#     440 name (str): The package name.
#    (...)
#     450 RETURNS (Language): The loaded nlp object.
#     451 """
#     452 cls = importlib.import_module(name)
# --> 453 return cls.load(vocab=vocab, disable=disable, exclude=exclude, config=config)
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/en_core_web_sm/__init__.py:12, in load(**overrides)
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/spacy/util.py:619, in load_model_from_init_py(init_file, vocab, disable, exclude, config)
#     617 if not model_path.exists():
#     618     raise IOError(Errors.E052.format(path=data_path))
# --> 619 return load_model_from_path(
#     620     data_path,
#     621     vocab=vocab,
#     622     meta=meta,
#     623     disable=disable,
#     624     exclude=exclude,
#     625     config=config,
#     626 )
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/spacy/util.py:487, in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
#     485 config_path = model_path / "config.cfg"
#     486 overrides = dict_to_dot(config)
# --> 487 config = load_config(config_path, overrides=overrides)
#     488 nlp = load_model_from_config(
#     489     config, vocab=vocab, disable=disable, exclude=exclude, meta=meta
#     490 )
#     491 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File ~/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/spacy/util.py:650, in load_config(path, overrides, interpolate)
#     648 else:
#     649     if not config_path or not config_path.is_file():
# --> 650         raise IOError(Errors.E053.format(path=config_path, name="config file"))
#     651     return config.from_disk(
#     652         config_path, overrides=overrides, interpolate=interpolate
#     653     )
#
# OSError: [E053] Could not read config file from /home/kky8822/.local/share/virtualenvs/2022_AI_expert-VdvU_stD/lib/python3.10/site-packages/en_core_web_sm/en_core_web_sm-2.2.0/config.cfg

# %%
doc = nlp(u"The quick brown fox jumped over the lazy dog's back.")
print(doc.text)
# Out:
# The quick brown fox jumped over the lazy dog's back.

# %%
print(doc)

# %%
print([w for w in doc])
print([w.pos_ for w in doc])
# Out:
# [The, quick, brown, fox, jumped, over, the, lazy, dog, 's, back, .]
# ['DET', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'PART', 'NOUN', 'PUNCT']

# %%
[w for w in doc][4].tag_
#[w for w in "The quick brown fox jumped over the lazy dog's back."]
# Out:
# 'VBD'

# %%
# a word's type: 
# tags could be found in 'https://spacy.io/api/annotation#pos-tagging'
doc[4].pos_, doc[4].tag_

# %%
# for tags explanation spacy.explain method can be used
spacy.explain('VBD')
# Out:
# 'verb, past tense'

# %%
# iterating over tokens and printing details
for token in doc:
    print(f"{token.text:{10}} {token.pos_:{10}} {token.tag_:{10}} {spacy.explain(token.tag_)}")
# Out:
# The        DET        DT         determiner
# quick      ADJ        JJ         adjective
# brown      ADJ        JJ         adjective
# fox        NOUN       NN         noun, singular or mass
# jumped     VERB       VBD        verb, past tense
# over       ADP        IN         conjunction, subordinating or preposition
# the        DET        DT         determiner
# lazy       ADJ        JJ         adjective
# dog        NOUN       NN         noun, singular or mass
# 's         PART       POS        possessive ending
# back       NOUN       NN         noun, singular or mass
# .          PUNCT      .          punctuation mark, sentence closer

# %% [markdown]
# ## Coarse-grained Part-of-speech Tags
# Every token is assigned a POS Tag from the following list:
#
#
# <table><tr><th>POS</th><th>DESCRIPTION</th><th>EXAMPLES</th></tr>
#
# <tr><td>ADJ</td><td>adjective</td><td>*big, old, green, incomprehensible, first*</td></tr>
# <tr><td>ADP</td><td>adposition</td><td>*in, to, during*</td></tr>
# <tr><td>ADV</td><td>adverb</td><td>*very, tomorrow, down, where, there*</td></tr>
# <tr><td>AUX</td><td>auxiliary</td><td>*is, has (done), will (do), should (do)*</td></tr>
# <tr><td>CONJ</td><td>conjunction</td><td>*and, or, but*</td></tr>
# <tr><td>CCONJ</td><td>coordinating conjunction</td><td>*and, or, but*</td></tr>
# <tr><td>DET</td><td>determiner</td><td>*a, an, the*</td></tr>
# <tr><td>INTJ</td><td>interjection</td><td>*psst, ouch, bravo, hello*</td></tr>
# <tr><td>NOUN</td><td>noun</td><td>*girl, cat, tree, air, beauty*</td></tr>
# <tr><td>NUM</td><td>numeral</td><td>*1, 2017, one, seventy-seven, IV, MMXIV*</td></tr>
# <tr><td>PART</td><td>particle</td><td>*'s, not,*</td></tr>
# <tr><td>PRON</td><td>pronoun</td><td>*I, you, he, she, myself, themselves, somebody*</td></tr>
# <tr><td>PROPN</td><td>proper noun</td><td>*Mary, John, London, NATO, HBO*</td></tr>
# <tr><td>PUNCT</td><td>punctuation</td><td>*., (, ), ?*</td></tr>
# <tr><td>SCONJ</td><td>subordinating conjunction</td><td>*if, while, that*</td></tr>
# <tr><td>SYM</td><td>symbol</td><td>*$, %, §, ©, +, −, ×, ÷, =, :), 😝*</td></tr>
# <tr><td>VERB</td><td>verb</td><td>*run, runs, running, eat, ate, eating*</td></tr>
# <tr><td>X</td><td>other</td><td>*sfpksdpsxmsa*</td></tr>
# <tr><td>SPACE</td><td>space</td></tr>

# %% [markdown]
# ___
# ## Fine-grained Part-of-speech Tags
# Tokens are subsequently given a fine-grained tag as determined by morphology:
# <table>
# <tr><th>POS</th><th>Description</th><th>Fine-grained Tag</th><th>Description</th><th>Morphology</th></tr>
# <tr><td>ADJ</td><td>adjective</td><td>AFX</td><td>affix</td><td>Hyph=yes</td></tr>
# <tr><td>ADJ</td><td></td><td>JJ</td><td>adjective</td><td>Degree=pos</td></tr>
# <tr><td>ADJ</td><td></td><td>JJR</td><td>adjective, comparative</td><td>Degree=comp</td></tr>
# <tr><td>ADJ</td><td></td><td>JJS</td><td>adjective, superlative</td><td>Degree=sup</td></tr>
# <tr><td>ADJ</td><td></td><td>PDT</td><td>predeterminer</td><td>AdjType=pdt PronType=prn</td></tr>
# <tr><td>ADJ</td><td></td><td>PRP\$</td><td>pronoun, possessive</td><td>PronType=prs Poss=yes</td></tr>
# <tr><td>ADJ</td><td></td><td>WDT</td><td>wh-determiner</td><td>PronType=int rel</td></tr>
# <tr><td>ADJ</td><td></td><td>WP\$</td><td>wh-pronoun, possessive</td><td>Poss=yes PronType=int rel</td></tr>
# <tr><td>ADP</td><td>adposition</td><td>IN</td><td>conjunction, subordinating or preposition</td><td></td></tr>
# <tr><td>ADV</td><td>adverb</td><td>EX</td><td>existential there</td><td>AdvType=ex</td></tr>
# <tr><td>ADV</td><td></td><td>RB</td><td>adverb</td><td>Degree=pos</td></tr>
# <tr><td>ADV</td><td></td><td>RBR</td><td>adverb, comparative</td><td>Degree=comp</td></tr>
# <tr><td>ADV</td><td></td><td>RBS</td><td>adverb, superlative</td><td>Degree=sup</td></tr>
# <tr><td>ADV</td><td></td><td>WRB</td><td>wh-adverb</td><td>PronType=int rel</td></tr>
# <tr><td>CONJ</td><td>conjunction</td><td>CC</td><td>conjunction, coordinating</td><td>ConjType=coor</td></tr>
# <tr><td>DET</td><td>determiner</td><td>DT</td><td>determiner</td><td></td></tr>
# <tr><td>INTJ</td><td>interjection</td><td>UH</td><td>interjection</td><td></td></tr>
# <tr><td>NOUN</td><td>noun</td><td>NN</td><td>noun, singular or mass</td><td>Number=sing</td></tr>
# <tr><td>NOUN</td><td></td><td>NNS</td><td>noun, plural</td><td>Number=plur</td></tr>
# <tr><td>NOUN</td><td></td><td>WP</td><td>wh-pronoun, personal</td><td>PronType=int rel</td></tr>
# <tr><td>NUM</td><td>numeral</td><td>CD</td><td>cardinal number</td><td>NumType=card</td></tr>
# <tr><td>PART</td><td>particle</td><td>POS</td><td>possessive ending</td><td>Poss=yes</td></tr>
# <tr><td>PART</td><td></td><td>RP</td><td>adverb, particle</td><td></td></tr>
# <tr><td>PART</td><td></td><td>TO</td><td>infinitival to</td><td>PartType=inf VerbForm=inf</td></tr>
# <tr><td>PRON</td><td>pronoun</td><td>PRP</td><td>pronoun, personal</td><td>PronType=prs</td></tr>
# <tr><td>PROPN</td><td>proper noun</td><td>NNP</td><td>noun, proper singular</td><td>NounType=prop Number=sign</td></tr>
# <tr><td>PROPN</td><td></td><td>NNPS</td><td>noun, proper plural</td><td>NounType=prop Number=plur</td></tr>
# <tr><td>PUNCT</td><td>punctuation</td><td>-LRB-</td><td>left round bracket</td><td>PunctType=brck PunctSide=ini</td></tr>
# <tr><td>PUNCT</td><td></td><td>-RRB-</td><td>right round bracket</td><td>PunctType=brck PunctSide=fin</td></tr>
# <tr><td>PUNCT</td><td></td><td>,</td><td>punctuation mark, comma</td><td>PunctType=comm</td></tr>
# <tr><td>PUNCT</td><td></td><td>:</td><td>punctuation mark, colon or ellipsis</td><td></td></tr>
# <tr><td>PUNCT</td><td></td><td>.</td><td>punctuation mark, sentence closer</td><td>PunctType=peri</td></tr>
# <tr><td>PUNCT</td><td></td><td>''</td><td>closing quotation mark</td><td>PunctType=quot PunctSide=fin</td></tr>
# <tr><td>PUNCT</td><td></td><td>""</td><td>closing quotation mark</td><td>PunctType=quot PunctSide=fin</td></tr>
# <tr><td>PUNCT</td><td></td><td>``</td><td>opening quotation mark</td><td>PunctType=quot PunctSide=ini</td></tr>
# <tr><td>PUNCT</td><td></td><td>HYPH</td><td>punctuation mark, hyphen</td><td>PunctType=dash</td></tr>
# <tr><td>PUNCT</td><td></td><td>LS</td><td>list item marker</td><td>NumType=ord</td></tr>
# <tr><td>PUNCT</td><td></td><td>NFP</td><td>superfluous punctuation</td><td></td></tr>
# <tr><td>SYM</td><td>symbol</td><td>#</td><td>symbol, number sign</td><td>SymType=numbersign</td></tr>
# <tr><td>SYM</td><td></td><td>\$</td><td>symbol, currency</td><td>SymType=currency</td></tr>
# <tr><td>SYM</td><td></td><td>SYM</td><td>symbol</td><td></td></tr>
# <tr><td>VERB</td><td>verb</td><td>BES</td><td>auxiliary "be"</td><td></td></tr>
# <tr><td>VERB</td><td></td><td>HVS</td><td>forms of "have"</td><td></td></tr>
# <tr><td>VERB</td><td></td><td>MD</td><td>verb, modal auxiliary</td><td>VerbType=mod</td></tr>
# <tr><td>VERB</td><td></td><td>VB</td><td>verb, base form</td><td>VerbForm=inf</td></tr>
# <tr><td>VERB</td><td></td><td>VBD</td><td>verb, past tense</td><td>VerbForm=fin Tense=past</td></tr>
# <tr><td>VERB</td><td></td><td>VBG</td><td>verb, gerund or present participle</td><td>VerbForm=part Tense=pres Aspect=prog</td></tr>
# <tr><td>VERB</td><td></td><td>VBN</td><td>verb, past participle</td><td>VerbForm=part Tense=past Aspect=perf</td></tr>
# <tr><td>VERB</td><td></td><td>VBP</td><td>verb, non-3rd person singular present</td><td>VerbForm=fin Tense=pres</td></tr>
# <tr><td>VERB</td><td></td><td>VBZ</td><td>verb, 3rd person singular present</td><td>VerbForm=fin Tense=pres Number=sing Person=3</td></tr>
# <tr><td>X</td><td>other</td><td>ADD</td><td>email</td><td></td></tr>
# <tr><td>X</td><td></td><td>FW</td><td>foreign word</td><td>Foreign=yes</td></tr>
# <tr><td>X</td><td></td><td>GW</td><td>additional word in multi-word expression</td><td></td></tr>
# <tr><td>X</td><td></td><td>XX</td><td>unknown</td><td></td></tr>
# <tr><td>SPACE</td><td>space</td><td>_SP</td><td>space</td><td></td></tr>
# <tr><td></td><td></td><td>NIL</td><td>missing tag</td><td></td></tr>
# </table>
#
# https://spacy.io/api/annotation#pos-tagging

# %%
# comparing different tenses 
doc1 = nlp(u"I read books on NLP.")
token1 = doc1[1]
print(f"{token1.text:{10}} {token1.pos_:{10}} {token1.tag_:{10}} {spacy.explain(token1.tag_)}")

# %%
# comparing different tenses 
doc1 = nlp(u"I like to read books on NLP.")
token1 = doc1[3]
print(f"{token1.text:{10}} {token1.pos_:{10}} {token1.tag_:{10}} {spacy.explain(token1.tag_)}")

# %%
token1.pos

# %%
doc2 = nlp(u"I read a book on NLP.")
token2 = doc2[1]
print(f"{token2.text:{10}} {token2.pos_:{10}} {token2.tag_:{10}} {spacy.explain(token2.tag_)}")

# %%
# counting the words according to their type
pos_counts = doc.count_by(spacy.attrs.POS)
pos_counts

# %%
# type of a word by its POS
doc.vocab[84].text

# %%
# type of a word by its part of speech
doc[2].pos_

# %%
# listing the counts and type of each pos
for k,v in sorted(pos_counts.items()):
    print(f"{k}. {doc.vocab[k].text:{5}} {v}")

# %%
# listing the counts and type of each tag
tag_counts = doc.count_by(spacy.attrs.TAG)
for k,v in sorted(tag_counts.items()):
    print(f"{k}. {doc.vocab[k].text:{5}} {v}")

# %%
# listing the counts and type of each dep
dep_counts = doc.count_by(spacy.attrs.DEP)
for k,v in sorted(dep_counts.items()):
    print(f"{k}. {doc.vocab[k].text:{5}} {v}")

# %% [markdown]
# ___
# ## Fine-grained POS Tag Examples
# These are some grammatical examples (shown in **bold**) of specific fine-grained tags. We've removed punctuation and rarely used tags:
# <table>
# <tr><th>POS</th><th>TAG</th><th>DESCRIPTION</th><th>EXAMPLE</th></tr>
# <tr><td>ADJ</td><td>AFX</td><td>affix</td><td>The Flintstones were a **pre**-historic family.</td></tr>
# <tr><td>ADJ</td><td>JJ</td><td>adjective</td><td>This is a **good** sentence.</td></tr>
# <tr><td>ADJ</td><td>JJR</td><td>adjective, comparative</td><td>This is a **better** sentence.</td></tr>
# <tr><td>ADJ</td><td>JJS</td><td>adjective, superlative</td><td>This is the **best** sentence.</td></tr>
# <tr><td>ADJ</td><td>PDT</td><td>predeterminer</td><td>Waking up is **half** the battle.</td></tr>
# <tr><td>ADJ</td><td>PRP\$</td><td>pronoun, possessive</td><td>**His** arm hurts.</td></tr>
# <tr><td>ADJ</td><td>WDT</td><td>wh-determiner</td><td>It's blue, **which** is odd.</td></tr>
# <tr><td>ADJ</td><td>WP\$</td><td>wh-pronoun, possessive</td><td>We don't know **whose** it is.</td></tr>
# <tr><td>ADP</td><td>IN</td><td>conjunction, subordinating or preposition</td><td>It arrived **in** a box.</td></tr>
# <tr><td>ADV</td><td>EX</td><td>existential there</td><td>**There** is cake.</td></tr>
# <tr><td>ADV</td><td>RB</td><td>adverb</td><td>He ran **quickly**.</td></tr>
# <tr><td>ADV</td><td>RBR</td><td>adverb, comparative</td><td>He ran **quicker**.</td></tr>
# <tr><td>ADV</td><td>RBS</td><td>adverb, superlative</td><td>He ran **fastest**.</td></tr>
# <tr><td>ADV</td><td>WRB</td><td>wh-adverb</td><td>**When** was that?</td></tr>
# <tr><td>CONJ</td><td>CC</td><td>conjunction, coordinating</td><td>The balloon popped **and** everyone jumped.</td></tr>
# <tr><td>DET</td><td>DT</td><td>determiner</td><td>**This** is **a** sentence.</td></tr>
# <tr><td>INTJ</td><td>UH</td><td>interjection</td><td>**Um**, I don't know.</td></tr>
# <tr><td>NOUN</td><td>NN</td><td>noun, singular or mass</td><td>This is a **sentence**.</td></tr>
# <tr><td>NOUN</td><td>NNS</td><td>noun, plural</td><td>These are **words**.</td></tr>
# <tr><td>NOUN</td><td>WP</td><td>wh-pronoun, personal</td><td>**Who** was that?</td></tr>
# <tr><td>NUM</td><td>CD</td><td>cardinal number</td><td>I want **three** things.</td></tr>
# <tr><td>PART</td><td>POS</td><td>possessive ending</td><td>Fred**'s** name is short.</td></tr>
# <tr><td>PART</td><td>RP</td><td>adverb, particle</td><td>Put it **back**!</td></tr>
# <tr><td>PART</td><td>TO</td><td>infinitival to</td><td>I want **to** go.</td></tr>
# <tr><td>PRON</td><td>PRP</td><td>pronoun, personal</td><td>**I** want **you** to go.</td></tr>
# <tr><td>PROPN</td><td>NNP</td><td>noun, proper singular</td><td>**Kilroy** was here.</td></tr>
# <tr><td>PROPN</td><td>NNPS</td><td>noun, proper plural</td><td>The **Flintstones** were a pre-historic family.</td></tr>
# <tr><td>VERB</td><td>MD</td><td>verb, modal auxiliary</td><td>This **could** work.</td></tr>
# <tr><td>VERB</td><td>VB</td><td>verb, base form</td><td>I want to **go**.</td></tr>
# <tr><td>VERB</td><td>VBD</td><td>verb, past tense</td><td>This **was** a sentence.</td></tr>
# <tr><td>VERB</td><td>VBG</td><td>verb, gerund or present participle</td><td>I am **going**.</td></tr>
# <tr><td>VERB</td><td>VBN</td><td>verb, past participle</td><td>The treasure was **lost**.</td></tr>
# <tr><td>VERB</td><td>VBP</td><td>verb, non-3rd person singular present</td><td>I **want** to go.</td></tr>
# <tr><td>VERB</td><td>VBZ</td><td>verb, 3rd person singular present</td><td>He **wants** to go.</td></tr>
# </table>

# %% [markdown]
# ### visualizing POS

# %%
from spacy import displacy

# %%
doc = nlp(u"The quick brown fox jumped over the lazy dog's back.")

# %%
# defaulşt syntactic visualization
displacy.render(doc, style='dep', jupyter=True)

# %%
# modifying the visual
options = {'distance':100, 'compact':'True','color':'white', 'bg':'#09a3d5', 'font':'Times'}
displacy.render(doc, style='dep', jupyter=True, options=options)

# %%
doc3 = nlp(u"This is a sentence. This is another sentence, possibly longer than other.")
spans = list(doc3.sents)

# %%
list(doc3.sents)[-1]

# %% [markdown]
# ### named entity recognition (NER)

# %%
def show_ents(doc):
    if doc.ents:
        for entity in doc.ents:
            print(entity.text + " - " + entity.label_ + " - " + spacy.explain(entity.label_) )
    else:
        print("No entity found!")

# %%
doc4 = nlp(u"Hi, how are you?")
show_ents(doc4)

# %%
doc5 = nlp(u"May I go to Washington, DC next May to see the Washington Monument? or Can I have 500 dollars Microsoft stock?")
show_ents(doc5)

# %% [markdown]
# ## Entity annotations
# `Doc.ents` are token spans with their own set of annotations.
# <table>
# <tr><td>`ent.text`</td><td>The original entity text</td></tr>
# <tr><td>`ent.label`</td><td>The entity type's hash value</td></tr>
# <tr><td>`ent.label_`</td><td>The entity type's string description</td></tr>
# <tr><td>`ent.start`</td><td>The token span's *start* index position in the Doc</td></tr>
# <tr><td>`ent.end`</td><td>The token span's *stop* index position in the Doc</td></tr>
# <tr><td>`ent.start_char`</td><td>The entity text's *start* index position in the Doc</td></tr>
# <tr><td>`ent.end_char`</td><td>The entity text's *stop* index position in the Doc</td></tr>
# </table>

# %%
doc6 = nlp(u"Google to build a U.K. facotyr for $6 million.")
show_ents(doc6)
# notice that 'Google' isn't recognized as an 'ORG' entity

# %% [markdown]
# ## NER Tags
# Tags are accessible through the `.label_` property of an entity.
# <table>
# <tr><th>TYPE</th><th>DESCRIPTION</th><th>EXAMPLE</th></tr>
# <tr><td>`PERSON`</td><td>People, including fictional.</td><td>*Fred Flintstone*</td></tr>
# <tr><td>`NORP`</td><td>Nationalities or religious or political groups.</td><td>*The Republican Party*</td></tr>
# <tr><td>`FAC`</td><td>Buildings, airports, highways, bridges, etc.</td><td>*Logan International Airport, The Golden Gate*</td></tr>
# <tr><td>`ORG`</td><td>Companies, agencies, institutions, etc.</td><td>*Microsoft, FBI, MIT*</td></tr>
# <tr><td>`GPE`</td><td>Countries, cities, states.</td><td>*France, UAR, Chicago, Idaho*</td></tr>
# <tr><td>`LOC`</td><td>Non-GPE locations, mountain ranges, bodies of water.</td><td>*Europe, Nile River, Midwest*</td></tr>
# <tr><td>`PRODUCT`</td><td>Objects, vehicles, foods, etc. (Not services.)</td><td>*Formula 1*</td></tr>
# <tr><td>`EVENT`</td><td>Named hurricanes, battles, wars, sports events, etc.</td><td>*Olympic Games*</td></tr>
# <tr><td>`WORK_OF_ART`</td><td>Titles of books, songs, etc.</td><td>*The Mona Lisa*</td></tr>
# <tr><td>`LAW`</td><td>Named documents made into laws.</td><td>*Roe v. Wade*</td></tr>
# <tr><td>`LANGUAGE`</td><td>Any named language.</td><td>*English*</td></tr>
# <tr><td>`DATE`</td><td>Absolute or relative dates or periods.</td><td>*20 July 1969*</td></tr>
# <tr><td>`TIME`</td><td>Times smaller than a day.</td><td>*Four hours*</td></tr>
# <tr><td>`PERCENT`</td><td>Percentage, including "%".</td><td>*Eighty percent*</td></tr>
# <tr><td>`MONEY`</td><td>Monetary values, including unit.</td><td>*Twenty Cents*</td></tr>
# <tr><td>`QUANTITY`</td><td>Measurements, as of weight or distance.</td><td>*Several kilometers, 55kg*</td></tr>
# <tr><td>`ORDINAL`</td><td>"first", "second", etc.</td><td>*9th, Ninth*</td></tr>
# <tr><td>`CARDINAL`</td><td>Numerals that do not fall under another type.</td><td>*2, Two, Fifty-two*</td></tr>
# </table>

# %%
# adding a word to the NER dictionary
from spacy.tokens import Span
# obtaining hash value of the entity label
ORG = doc6.vocab.strings[u"ORG"]
# creating a span for 'Google' in doc5 start=0, end=1
new_ent = Span(doc6, 0 , 1, label=ORG)
# adding entity to the entity list 
#doc6.ents = list(doc6.ents) + [new_ent]
show_ents(doc6)

# %%
doc7 = nlp(u"Our company created a brand new vacuum cleaner."
          u"This new vacuum-cleaner is the best in show.")
show_ents(doc7)

# %%
from spacy.matcher import PhraseMatcher
# creating matcher object
matcher = PhraseMatcher(nlp.vocab)
# creating phrase list
phrase_list = ['vacuum cleaner', 'vacuum-cleaner']
# creating phrase patterns for phrase list
phrase_patterns = [nlp(text) for text in phrase_list]
# adding phrase patterns to matcher
matcher.add('newproduct', None, *phrase_patterns)
# finding the matches
found_matches = matcher(doc7)
found_matches

# %%
from spacy.tokens import Span
PROD = doc7.vocab.strings[u"PRODUCT"]
new_ents = [Span(doc7, match[1], match[2], label=PROD) for match in found_matches]
doc7.ents = list(doc7.ents) + new_ents
show_ents(doc7)

# %%
doc8 = nlp(u"Originally I paid $29.95 for a toy and now it is marked as 15 dollars.")

# %%
money_entities = [ent for ent in doc8.ents if ent.label_ == "MONEY"]
money_entities

# %% [markdown]
# ### visualizing NER

# %%
from spacy import displacy
doc9 = nlp(u"Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million."
          u"By contrast, Sony only sold 8 thousand Walkman music players.")

# %%
displacy.render(doc9, style = 'ent', jupyter=True)

# %%
# displaying the visual sentence by sentence
for sent in doc9.sents:
    displacy.render(sent, style = 'ent', jupyter=True)

# %%
# defining option s dictionary to change options of visual
colors = {'ORG':'red'}
options = {'ents':['PRODUCT', 'ORG'], 'colors' : colors}
displacy.render(doc9, style = 'ent', jupyter=True, options=options)

# %% [markdown]
# ## **Applications and State of the Art**
#
# [HMTL (Hierarchical Multi-Task Learning model) Demo](https://huggingface.co/hmtl/)
#
# [HMTL (Hierarchical Multi-Task Learning model) Code](https://github.com/huggingface/hmtl)
#
# ![picture](https://github.com/huggingface/hmtl/raw/master/HMTL_architecture.png)

# %% [markdown]
# ![picture](https://www.ibm.com/blogs/research/wp-content/uploads/2016/10/alexsmith2.jpg)
